# %% [markdown]
# ### Initial Hotspot Prediction Model
# ##### Goal: Identify high-demand zones at specific times, based on historical trip pickup patterns

# %% [markdown]
# #### Load Trip Data

# %%
import os
from datetime import datetime
from collections import Counter
from tkinter import Tk
from tkinter.filedialog import askopenfilename

import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import seaborn as sns

from shapely.geometry import Polygon

from sklearn.model_selection import (
    KFold, train_test_split, GridSearchCV
)
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import (
    mean_absolute_error, mean_squared_error, r2_score,
    f1_score, roc_auc_score, confusion_matrix,
    precision_score, recall_score, accuracy_score
)

import lightgbm as lgb
from lightgbm import (
    early_stopping, log_evaluation,
    LGBMRegressor, plot_importance
)

import xgboost as xgb
from xgboost import XGBClassifier, XGBRegressor

# %%
# Load your dataset
print("Current working directory:", os.getcwd())

# Let user select their local file
#Tk().withdraw()  # Hide the root window
file_path = askopenfilename(title="Select your local final cleaned taxi data CSV")

# Check and load
if not file_path or not os.path.exists(file_path):
    raise FileNotFoundError("File not found or not selected.")
else:
    trip_counts = pd.read_csv(file_path)
    print("Loaded file:", file_path)
    print("Initial shape:", trip_counts.shape)
print(f"Dataset loaded successfully! Shape: {trip_counts.shape}")
print(f"Columns: {list(trip_counts.columns)}")
# Out:
# Current working directory: /Users/elliekavanagh/TaxiApp/Notebooks/Hotspot Prediction Model
# Loaded file: /Users/elliekavanagh/Downloads/Trip_Counts_Jan_to_Apr.csv
# Initial shape: (147211, 11)
# Dataset loaded successfully! Shape: (147211, 11)
# Columns: ['pickup_date', 'pickup_hour', 'pickup_zone', 'pickup_borough', 'day_type', 'pickup_month', 'pickup_day_of_week', 'is_weekend', 'time_of_day', 'is_holiday', 'trip_count']

# %% [markdown]
# #### Shapefile Adjacency List

# %%
# Prompt user to select a shapefile
shapefile_path = askopenfilename(title="Select your shapefile")

# Check and load
if not shapefile_path or not os.path.exists(shapefile_path):
    raise FileNotFoundError("File not found or not selected.")

# Read shapefile using GeoPandas
gdf = gpd.read_file(shapefile_path)
print("Loaded shapefile:", shapefile_path)
print("Initial shape:", gdf.shape)
print("Columns:", list(gdf.columns))

# Define the name of the zone column (update this if needed)
zone_column = "zone"
# Out:
# Loaded shapefile: /Users/elliekavanagh/Downloads/taxi_zones (1)/taxi_zones.shp
# Initial shape: (263, 7)
# Columns: ['OBJECTID', 'Shape_Leng', 'Shape_Area', 'zone', 'LocationID', 'borough', 'geometry']

# %%
gdf
# Out:
#      OBJECTID  Shape_Leng  Shape_Area                     zone  LocationID  \
# 0           1    0.116357    0.000782           Newark Airport           1
# 1           2    0.433470    0.004866              Jamaica Bay           2
# 2           3    0.084341    0.000314  Allerton/Pelham Gardens           3
# 3           4    0.043567    0.000112            Alphabet City           4
# 4           5    0.092146    0.000498            Arden Heights           5
# ..        ...         ...         ...                      ...         ...
# 258       259    0.126750    0.000395       Woodlawn/Wakefield         259
# 259       260    0.133514    0.000422                 Woodside         260
# 260       261    0.027120    0.000034       World Trade Center         261
# 261       262    0.049064    0.000122           Yorkville East         262
# 262       263    0.037017    0.000066           Yorkville West         263
#
#            borough                                           geometry
# 0              EWR  POLYGON ((933100.918 192536.086, 933091.011 19...
# 1           Queens  MULTIPOLYGON (((1033269.244 172126.008, 103343...
# 2            Bronx  POLYGON ((1026308.77 256767.698, 1026495.593 2...
# 3        Manhattan  POLYGON ((992073.467 203714.076, 992068.667 20...
# 4    Staten Island  POLYGON ((935843.31 144283.336, 936046.565 144...
# ..             ...                                                ...
# 258          Bronx  POLYGON ((1025414.782 270986.139, 1025138.624 ...
# 259         Queens  POLYGON ((1011466.966 216463.005, 1011545.889 ...
# 260      Manhattan  POLYGON ((980555.204 196138.486, 980570.792 19...
# 261      Manhattan  MULTIPOLYGON (((999804.795 224498.527, 999824....
# 262      Manhattan  POLYGON ((997493.323 220912.386, 997355.264 22...
#
# [263 rows x 7 columns]

# %%
# Assume gdf is your original GeoDataFrame in projected CRS (e.g., EPSG:2263)
# Step 1: Convert gdf to EPSG:4326 (WGS84 lat/lon)
gdf_latlon = gdf.to_crs(epsg=4326)

# Step 2: Calculate centroid in lat/lon CRS
gdf_latlon['centroid'] = gdf_latlon.geometry.centroid

# Step 3: Extract latitude and longitude from centroid points
gdf_latlon['centroid_lat'] = gdf_latlon.centroid.y
gdf_latlon['centroid_lon'] = gdf_latlon.centroid.x

# Optional: If you want to keep other columns from original gdf, merge back or just continue working with gdf_latlon
# For example, assign back to original gdf (be mindful that gdf stays in original CRS)
gdf['centroid_lat'] = gdf_latlon['centroid_lat']
gdf['centroid_lon'] = gdf_latlon['centroid_lon']
# Out:
# /var/folders/jx/f68bh07x2yj9wm1y4w06hh040000gn/T/ipykernel_60954/2075913059.py:6: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf_latlon['centroid'] = gdf_latlon.geometry.centroid
# /var/folders/jx/f68bh07x2yj9wm1y4w06hh040000gn/T/ipykernel_60954/2075913059.py:9: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf_latlon['centroid_lat'] = gdf_latlon.centroid.y
# /var/folders/jx/f68bh07x2yj9wm1y4w06hh040000gn/T/ipykernel_60954/2075913059.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf_latlon['centroid_lon'] = gdf_latlon.centroid.x

# %%
gdf
# Out:
#      OBJECTID  Shape_Leng  Shape_Area                     zone  LocationID  \
# 0           1    0.116357    0.000782           Newark Airport           1
# 1           2    0.433470    0.004866              Jamaica Bay           2
# 2           3    0.084341    0.000314  Allerton/Pelham Gardens           3
# 3           4    0.043567    0.000112            Alphabet City           4
# 4           5    0.092146    0.000498            Arden Heights           5
# ..        ...         ...         ...                      ...         ...
# 258       259    0.126750    0.000395       Woodlawn/Wakefield         259
# 259       260    0.133514    0.000422                 Woodside         260
# 260       261    0.027120    0.000034       World Trade Center         261
# 261       262    0.049064    0.000122           Yorkville East         262
# 262       263    0.037017    0.000066           Yorkville West         263
#
#            borough                                           geometry  \
# 0              EWR  POLYGON ((933100.918 192536.086, 933091.011 19...
# 1           Queens  MULTIPOLYGON (((1033269.244 172126.008, 103343...
# 2            Bronx  POLYGON ((1026308.77 256767.698, 1026495.593 2...
# 3        Manhattan  POLYGON ((992073.467 203714.076, 992068.667 20...
# 4    Staten Island  POLYGON ((935843.31 144283.336, 936046.565 144...
# ..             ...                                                ...
# 258          Bronx  POLYGON ((1025414.782 270986.139, 1025138.624 ...
# 259         Queens  POLYGON ((1011466.966 216463.005, 1011545.889 ...
# 260      Manhattan  POLYGON ((980555.204 196138.486, 980570.792 19...
# 261      Manhattan  MULTIPOLYGON (((999804.795 224498.527, 999824....
# 262      Manhattan  POLYGON ((997493.323 220912.386, 997355.264 22...
#
#      centroid_lat  centroid_lon
# 0       40.691831    -74.174000
# 1       40.616745    -73.831299
# 2       40.864474    -73.847422
# 3       40.723752    -73.976968
# 4       40.552659    -74.188484
# ..            ...           ...
# 258     40.897932    -73.852215
# 259     40.744235    -73.906306
# 260     40.709139    -74.013023
# 261     40.775932    -73.946510
# 262     40.778766    -73.951010
#
# [263 rows x 9 columns]

# %%
# Initialize adjacency list
adjacency_list = {zone: [] for zone in gdf[zone_column]}

# Build adjacency based on touching or nearly touching boundaries
for idx1, row1 in gdf.iterrows():
    zone1 = row1[zone_column] # Current zone
    geom1 = row1.geometry # Geometry of the current zone
    for idx2, row2 in gdf.iterrows():
        if idx1 != idx2: # Skip self-comparison
            zone2 = row2[zone_column]
            geom2 = row2.geometry
            # Check if two zones are adjacent
            if geom1.touches(geom2) or geom1.buffer(0.0001).intersects(geom2):
                adjacency_list[zone1].append(zone2) # Add zone2 as a neighbor of zone1

# Remove duplicates from adjacency list
adjacency_list = {k: list(set(v)) for k, v in adjacency_list.items()}

# %% [markdown]
# #### Preprocessing: Creating Datetime Features and Dropping Features

# %%
# Convert date columns to datetime
trip_counts['pickup_date'] = pd.to_datetime(trip_counts['pickup_date'])
trip_counts['pickup_month'] = trip_counts['pickup_date'].dt.month

# %%
trip_counts['day_time_interaction'] = trip_counts['pickup_day_of_week'].astype(str) + "_" + trip_counts['time_of_day'].astype(str)
trip_counts['zone_hour_interaction'] = trip_counts['pickup_zone'].astype(str) + "_" + trip_counts['pickup_hour'].astype(str)
trip_counts['holiday_time_interaction'] = trip_counts['is_holiday'].astype(str) + '_' + trip_counts['time_of_day'].astype(str)
trip_counts['zone_isweekend_interaction'] = trip_counts['pickup_zone'].astype(str) + '_' + trip_counts['is_weekend'].astype(str)
trip_counts['hour_isweekend_interaction'] = trip_counts['pickup_hour'].astype(str) + '_' + trip_counts['is_weekend'].astype(str)
trip_counts['zone_time_isweekend_interaction'] = trip_counts['pickup_zone'].astype(str) + '_' + trip_counts['time_of_day'].astype(str) + "_" + trip_counts['is_weekend'].astype(str)
trip_counts['zone_hour_isweekend_interaction'] = trip_counts['pickup_zone'].astype(str) + '_' + trip_counts['pickup_hour'].astype(str) + "_" + trip_counts['is_weekend'].astype(str)
trip_counts['zone_hour_holiday_interaction'] = trip_counts['pickup_zone'].astype(str) + '_' + trip_counts['pickup_hour'].astype(str) + "_" + trip_counts['is_holiday'].astype(str)

# %% [markdown]
# **Discussion:** Drop post-trip features such as fare_amount and trip_duration_min, as they aren't know at prediction time.

# %% [markdown]
# #### Aggregating Trips By Zone, Pickup Time, and Day of Week

# %%
trip_counts = trip_counts.groupby(['pickup_date', 'pickup_hour', 'pickup_zone', 'pickup_borough', 'day_type', 'pickup_month', 'day_time_interaction', 
                          'zone_hour_interaction', 'zone_isweekend_interaction', 'holiday_time_interaction', 'hour_isweekend_interaction', 
                          'zone_time_isweekend_interaction', 'zone_hour_isweekend_interaction', 'zone_hour_holiday_interaction', 'pickup_day_of_week', 'is_weekend', 'time_of_day', 'is_holiday']).size().reset_index(name='trip_count')
trip_counts = trip_counts.sort_values(by=['pickup_date', 'pickup_hour'], ascending=[True, True])
trip_counts
# Out:
#        pickup_date  pickup_hour                pickup_zone pickup_borough  \
# 0       2023-01-01            0              Alphabet City      Manhattan
# 1       2023-01-01            0                    Astoria         Queens
# 2       2023-01-01            0               Battery Park      Manhattan
# 3       2023-01-01            0          Battery Park City      Manhattan
# 4       2023-01-01            0               Bloomingdale      Manhattan
# ...            ...          ...                        ...            ...
# 147206  2023-03-12            1  Williamsburg (South Side)       Brooklyn
# 147207  2023-03-12            1                   Woodside         Queens
# 147208  2023-03-12            1         World Trade Center      Manhattan
# 147209  2023-03-12            1             Yorkville East      Manhattan
# 147210  2023-03-12            1             Yorkville West      Manhattan
#
#        day_type  pickup_month day_time_interaction  \
# 0       Weekend             1      6_Early Morning
# 1       Weekend             1      6_Early Morning
# 2       Weekend             1      6_Early Morning
# 3       Weekend             1      6_Early Morning
# 4       Weekend             1      6_Early Morning
# ...         ...           ...                  ...
# 147206  Weekend             3      6_Early Morning
# 147207  Weekend             3      6_Early Morning
# 147208  Weekend             3      6_Early Morning
# 147209  Weekend             3      6_Early Morning
# 147210  Weekend             3      6_Early Morning
#
#               zone_hour_interaction      zone_isweekend_interaction  \
# 0                   Alphabet City_0              Alphabet City_True
# 1                         Astoria_0                    Astoria_True
# 2                    Battery Park_0               Battery Park_True
# 3               Battery Park City_0          Battery Park City_True
# 4                    Bloomingdale_0               Bloomingdale_True
# ...                             ...                             ...
# 147206  Williamsburg (South Side)_1  Williamsburg (South Side)_True
# 147207                   Woodside_1                   Woodside_True
# 147208         World Trade Center_1         World Trade Center_True
# 147209             Yorkville East_1             Yorkville East_True
# 147210             Yorkville West_1             Yorkville West_True
#
#        holiday_time_interaction hour_isweekend_interaction  \
# 0            True_Early Morning                     0_True
# 1            True_Early Morning                     0_True
# 2            True_Early Morning                     0_True
# 3            True_Early Morning                     0_True
# 4            True_Early Morning                     0_True
# ...                         ...                        ...
# 147206      False_Early Morning                     1_True
# 147207      False_Early Morning                     1_True
# 147208      False_Early Morning                     1_True
# 147209      False_Early Morning                     1_True
# 147210      False_Early Morning                     1_True
#
#                      zone_time_isweekend_interaction  \
# 0                   Alphabet City_Early Morning_True
# 1                         Astoria_Early Morning_True
# 2                    Battery Park_Early Morning_True
# 3               Battery Park City_Early Morning_True
# 4                    Bloomingdale_Early Morning_True
# ...                                              ...
# 147206  Williamsburg (South Side)_Early Morning_True
# 147207                   Woodside_Early Morning_True
# 147208         World Trade Center_Early Morning_True
# 147209             Yorkville East_Early Morning_True
# 147210             Yorkville West_Early Morning_True
#
#          zone_hour_isweekend_interaction      zone_hour_holiday_interaction  \
# 0                   Alphabet City_0_True               Alphabet City_0_True
# 1                         Astoria_0_True                     Astoria_0_True
# 2                    Battery Park_0_True                Battery Park_0_True
# 3               Battery Park City_0_True           Battery Park City_0_True
# 4                    Bloomingdale_0_True                Bloomingdale_0_True
# ...                                  ...                                ...
# 147206  Williamsburg (South Side)_1_True  Williamsburg (South Side)_1_False
# 147207                   Woodside_1_True                   Woodside_1_False
# 147208         World Trade Center_1_True         World Trade Center_1_False
# 147209             Yorkville East_1_True             Yorkville East_1_False
# 147210             Yorkville West_1_True             Yorkville West_1_False
#
#         pickup_day_of_week  is_weekend    time_of_day  is_holiday  trip_count
# 0                        6        True  Early Morning        True           1
# 1                        6        True  Early Morning        True           1
# 2                        6        True  Early Morning        True           1
# 3                        6        True  Early Morning        True           1
# 4                        6        True  Early Morning        True           1
# ...                    ...         ...            ...         ...         ...
# 147206                   6        True  Early Morning       False           1
# 147207                   6        True  Early Morning       False           1
# 147208                   6        True  Early Morning       False           1
# 147209                   6        True  Early Morning       False           1
# 147210                   6        True  Early Morning       False           1
#
# [147211 rows x 19 columns]

# %%
trip_counts = trip_counts.sort_values(['pickup_zone', 'pickup_hour'])
trip_counts.columns
# Out:
# Index(['pickup_date', 'pickup_hour', 'pickup_zone', 'pickup_borough',
#        'day_type', 'pickup_month', 'day_time_interaction',
#        'zone_hour_interaction', 'zone_isweekend_interaction',
#        'holiday_time_interaction', 'hour_isweekend_interaction',
#        'zone_time_isweekend_interaction', 'zone_hour_isweekend_interaction',
#        'zone_hour_holiday_interaction', 'pickup_day_of_week', 'is_weekend',
#        'time_of_day', 'is_holiday', 'trip_count'],
#       dtype='object')

# %%
trip_counts
# Out:
#        pickup_date  pickup_hour              pickup_zone pickup_borough  \
# 45732   2023-01-23            4  Allerton/Pelham Gardens          Bronx
# 6528    2023-01-04            6  Allerton/Pelham Gardens          Bronx
# 94063   2023-02-15            6  Allerton/Pelham Gardens          Bronx
# 106667  2023-02-21            6  Allerton/Pelham Gardens          Bronx
# 119453  2023-02-27            6  Allerton/Pelham Gardens          Bronx
# ...            ...          ...                      ...            ...
# 138356  2023-03-07           23           Yorkville West      Manhattan
# 140481  2023-03-08           23           Yorkville West      Manhattan
# 142726  2023-03-09           23           Yorkville West      Manhattan
# 145023  2023-03-10           23           Yorkville West      Manhattan
# 147044  2023-03-11           23           Yorkville West      Manhattan
#
#        day_type  pickup_month day_time_interaction      zone_hour_interaction  \
# 45732   Weekday             1      0_Early Morning  Allerton/Pelham Gardens_4
# 6528    Weekday             1       2_Morning Rush  Allerton/Pelham Gardens_6
# 94063   Weekday             2       2_Morning Rush  Allerton/Pelham Gardens_6
# 106667  Weekday             2       1_Morning Rush  Allerton/Pelham Gardens_6
# 119453  Weekday             2       0_Morning Rush  Allerton/Pelham Gardens_6
# ...         ...           ...                  ...                        ...
# 138356  Weekday             3       1_Evening Rush          Yorkville West_23
# 140481  Weekday             3       2_Evening Rush          Yorkville West_23
# 142726  Weekday             3       3_Evening Rush          Yorkville West_23
# 145023  Weekday             3       4_Evening Rush          Yorkville West_23
# 147044  Weekend             3       5_Evening Rush          Yorkville West_23
#
#            zone_isweekend_interaction holiday_time_interaction  \
# 45732   Allerton/Pelham Gardens_False      False_Early Morning
# 6528    Allerton/Pelham Gardens_False       False_Morning Rush
# 94063   Allerton/Pelham Gardens_False       False_Morning Rush
# 106667  Allerton/Pelham Gardens_False       False_Morning Rush
# 119453  Allerton/Pelham Gardens_False       False_Morning Rush
# ...                               ...                      ...
# 138356           Yorkville West_False       False_Evening Rush
# 140481           Yorkville West_False       False_Evening Rush
# 142726           Yorkville West_False       False_Evening Rush
# 145023           Yorkville West_False       False_Evening Rush
# 147044            Yorkville West_True       False_Evening Rush
#
#        hour_isweekend_interaction  \
# 45732                     4_False
# 6528                      6_False
# 94063                     6_False
# 106667                    6_False
# 119453                    6_False
# ...                           ...
# 138356                   23_False
# 140481                   23_False
# 142726                   23_False
# 145023                   23_False
# 147044                    23_True
#
#                     zone_time_isweekend_interaction  \
# 45732   Allerton/Pelham Gardens_Early Morning_False
# 6528     Allerton/Pelham Gardens_Morning Rush_False
# 94063    Allerton/Pelham Gardens_Morning Rush_False
# 106667   Allerton/Pelham Gardens_Morning Rush_False
# 119453   Allerton/Pelham Gardens_Morning Rush_False
# ...                                             ...
# 138356            Yorkville West_Evening Rush_False
# 140481            Yorkville West_Evening Rush_False
# 142726            Yorkville West_Evening Rush_False
# 145023            Yorkville West_Evening Rush_False
# 147044             Yorkville West_Evening Rush_True
#
#         zone_hour_isweekend_interaction    zone_hour_holiday_interaction  \
# 45732   Allerton/Pelham Gardens_4_False  Allerton/Pelham Gardens_4_False
# 6528    Allerton/Pelham Gardens_6_False  Allerton/Pelham Gardens_6_False
# 94063   Allerton/Pelham Gardens_6_False  Allerton/Pelham Gardens_6_False
# 106667  Allerton/Pelham Gardens_6_False  Allerton/Pelham Gardens_6_False
# 119453  Allerton/Pelham Gardens_6_False  Allerton/Pelham Gardens_6_False
# ...                                 ...                              ...
# 138356          Yorkville West_23_False          Yorkville West_23_False
# 140481          Yorkville West_23_False          Yorkville West_23_False
# 142726          Yorkville West_23_False          Yorkville West_23_False
# 145023          Yorkville West_23_False          Yorkville West_23_False
# 147044           Yorkville West_23_True          Yorkville West_23_False
#
#         pickup_day_of_week  is_weekend    time_of_day  is_holiday  trip_count
# 45732                    0       False  Early Morning       False           1
# 6528                     2       False   Morning Rush       False           1
# 94063                    2       False   Morning Rush       False           1
# 106667                   1       False   Morning Rush       False           1
# 119453                   0       False   Morning Rush       False           1
# ...                    ...         ...            ...         ...         ...
# 138356                   1       False   Evening Rush       False           1
# 140481                   2       False   Evening Rush       False           1
# 142726                   3       False   Evening Rush       False           1
# 145023                   4       False   Evening Rush       False           1
# 147044                   5        True   Evening Rush       False           1
#
# [147211 rows x 19 columns]

# %% [markdown]
# **Creating lag/rolling features:**
# Lag and rolling features capture temporal dependecies by only using past data to predict current demand.
#
# **Key steps:**
# 1. Combine date and hour (datetime) to order the data chronologically
# 2. Sort data by zone and datetime to ensure lag/rolling features only refer to earlier time points within each zone
# 3. Create lag features:
#     - trip_count_1h_ago uses the trip count from 1 hour prior
#     - trip_count_2h_ago uses the trip count from 2 hours prior
# Because these features reference past trip counts, the model can't access future information (preventing leakage)
# 4. Calculate rolling averages:
#     - rolling_avg_1h is based only on the previous hour
#     - rolling_avg_2h averages the two prior hours
# Rolling averages are also computed only using historical data, ensuring no current or forward-looking data is included
# 5. Handle missing lag values: Missing lag values are filled with zeros, maintaining dataset integrity without leaking future data
#
# **Avoiding data leakage:**
# By sorting trip_counts by datetime within each zone, the lag and rolling features are calculated using only past trip counts. This ensures that when the model sees data for a gifen hour, it does not have access to any information from the current or future hours, preventing data leakage.

# %%
trip_counts['datetime'] = pd.to_datetime(trip_counts['pickup_date']) + pd.to_timedelta(trip_counts['pickup_hour'], unit='h')
trip_counts = trip_counts.sort_values(['pickup_zone', 'datetime']).reset_index(drop=True)

# Create lag features (past trip counts)
trip_counts['trip_count_1h_ago'] = trip_counts.groupby('pickup_zone')['trip_count'].shift(1).fillna(0)
trip_counts['trip_count_2h_ago'] = trip_counts.groupby('pickup_zone')['trip_count'].shift(2).fillna(0)

# Rolling average for past 2 hours
trip_counts['rolling_avg_2h'] = (trip_counts['trip_count_1h_ago'] + trip_counts['trip_count_2h_ago']) / 2

trip_counts = trip_counts.drop(['datetime'], axis=1)

# %%
trip_counts
# Out:
#        pickup_date  pickup_hour              pickup_zone pickup_borough  \
# 0       2023-01-02           10  Allerton/Pelham Gardens          Bronx
# 1       2023-01-03           10  Allerton/Pelham Gardens          Bronx
# 2       2023-01-03           11  Allerton/Pelham Gardens          Bronx
# 3       2023-01-04            6  Allerton/Pelham Gardens          Bronx
# 4       2023-01-05            8  Allerton/Pelham Gardens          Bronx
# ...            ...          ...                      ...            ...
# 147206  2023-03-11           21           Yorkville West      Manhattan
# 147207  2023-03-11           22           Yorkville West      Manhattan
# 147208  2023-03-11           23           Yorkville West      Manhattan
# 147209  2023-03-12            0           Yorkville West      Manhattan
# 147210  2023-03-12            1           Yorkville West      Manhattan
#
#        day_type  pickup_month day_time_interaction  \
# 0       Weekday             1             0_Midday
# 1       Weekday             1             1_Midday
# 2       Weekday             1             1_Midday
# 3       Weekday             1       2_Morning Rush
# 4       Weekday             1       3_Morning Rush
# ...         ...           ...                  ...
# 147206  Weekend             3       5_Evening Rush
# 147207  Weekend             3       5_Evening Rush
# 147208  Weekend             3       5_Evening Rush
# 147209  Weekend             3      6_Early Morning
# 147210  Weekend             3      6_Early Morning
#
#              zone_hour_interaction     zone_isweekend_interaction  \
# 0       Allerton/Pelham Gardens_10  Allerton/Pelham Gardens_False
# 1       Allerton/Pelham Gardens_10  Allerton/Pelham Gardens_False
# 2       Allerton/Pelham Gardens_11  Allerton/Pelham Gardens_False
# 3        Allerton/Pelham Gardens_6  Allerton/Pelham Gardens_False
# 4        Allerton/Pelham Gardens_8  Allerton/Pelham Gardens_False
# ...                            ...                            ...
# 147206           Yorkville West_21            Yorkville West_True
# 147207           Yorkville West_22            Yorkville West_True
# 147208           Yorkville West_23            Yorkville West_True
# 147209            Yorkville West_0            Yorkville West_True
# 147210            Yorkville West_1            Yorkville West_True
#
#        holiday_time_interaction  ...   zone_hour_isweekend_interaction  \
# 0                   True_Midday  ...  Allerton/Pelham Gardens_10_False
# 1                  False_Midday  ...  Allerton/Pelham Gardens_10_False
# 2                  False_Midday  ...  Allerton/Pelham Gardens_11_False
# 3            False_Morning Rush  ...   Allerton/Pelham Gardens_6_False
# 4            False_Morning Rush  ...   Allerton/Pelham Gardens_8_False
# ...                         ...  ...                               ...
# 147206       False_Evening Rush  ...            Yorkville West_21_True
# 147207       False_Evening Rush  ...            Yorkville West_22_True
# 147208       False_Evening Rush  ...            Yorkville West_23_True
# 147209      False_Early Morning  ...             Yorkville West_0_True
# 147210      False_Early Morning  ...             Yorkville West_1_True
#
#            zone_hour_holiday_interaction pickup_day_of_week is_weekend  \
# 0        Allerton/Pelham Gardens_10_True                  0      False
# 1       Allerton/Pelham Gardens_10_False                  1      False
# 2       Allerton/Pelham Gardens_11_False                  1      False
# 3        Allerton/Pelham Gardens_6_False                  2      False
# 4        Allerton/Pelham Gardens_8_False                  3      False
# ...                                  ...                ...        ...
# 147206           Yorkville West_21_False                  5       True
# 147207           Yorkville West_22_False                  5       True
# 147208           Yorkville West_23_False                  5       True
# 147209            Yorkville West_0_False                  6       True
# 147210            Yorkville West_1_False                  6       True
#
#           time_of_day  is_holiday trip_count  trip_count_1h_ago  \
# 0              Midday        True          1                0.0
# 1              Midday       False          1                1.0
# 2              Midday       False          1                1.0
# 3        Morning Rush       False          1                1.0
# 4        Morning Rush       False          1                1.0
# ...               ...         ...        ...                ...
# 147206   Evening Rush       False          1                1.0
# 147207   Evening Rush       False          1                1.0
# 147208   Evening Rush       False          1                1.0
# 147209  Early Morning       False          1                1.0
# 147210  Early Morning       False          1                1.0
#
#         trip_count_2h_ago  rolling_avg_2h
# 0                     0.0             0.0
# 1                     0.0             0.5
# 2                     1.0             1.0
# 3                     1.0             1.0
# 4                     1.0             1.0
# ...                   ...             ...
# 147206                1.0             1.0
# 147207                1.0             1.0
# 147208                1.0             1.0
# 147209                1.0             1.0
# 147210                1.0             1.0
#
# [147211 rows x 22 columns]

# %%
trip_counts = trip_counts.sort_values(['trip_count'], ascending=False)
trip_counts
# Out:
#        pickup_date  pickup_hour              pickup_zone pickup_borough  \
# 0       2023-01-02           10  Allerton/Pelham Gardens          Bronx
# 98143   2023-02-17            7               Ocean Hill       Brooklyn
# 98137   2023-02-15            5               Ocean Hill       Brooklyn
# 98138   2023-02-15            8               Ocean Hill       Brooklyn
# 98139   2023-02-15           11               Ocean Hill       Brooklyn
# ...            ...          ...                      ...            ...
# 49064   2023-01-21           14            Fresh Meadows         Queens
# 49063   2023-01-20           13            Fresh Meadows         Queens
# 49062   2023-01-19           13            Fresh Meadows         Queens
# 49061   2023-01-19            8            Fresh Meadows         Queens
# 147210  2023-03-12            1           Yorkville West      Manhattan
#
#        day_type  pickup_month day_time_interaction  \
# 0       Weekday             1             0_Midday
# 98143   Weekday             2       4_Morning Rush
# 98137   Weekday             2       2_Morning Rush
# 98138   Weekday             2       2_Morning Rush
# 98139   Weekday             2             2_Midday
# ...         ...           ...                  ...
# 49064   Weekend             1             5_Midday
# 49063   Weekday             1             4_Midday
# 49062   Weekday             1             3_Midday
# 49061   Weekday             1       3_Morning Rush
# 147210  Weekend             3      6_Early Morning
#
#              zone_hour_interaction     zone_isweekend_interaction  \
# 0       Allerton/Pelham Gardens_10  Allerton/Pelham Gardens_False
# 98143                 Ocean Hill_7               Ocean Hill_False
# 98137                 Ocean Hill_5               Ocean Hill_False
# 98138                 Ocean Hill_8               Ocean Hill_False
# 98139                Ocean Hill_11               Ocean Hill_False
# ...                            ...                            ...
# 49064             Fresh Meadows_14             Fresh Meadows_True
# 49063             Fresh Meadows_13            Fresh Meadows_False
# 49062             Fresh Meadows_13            Fresh Meadows_False
# 49061              Fresh Meadows_8            Fresh Meadows_False
# 147210            Yorkville West_1            Yorkville West_True
#
#        holiday_time_interaction  ...   zone_hour_isweekend_interaction  \
# 0                   True_Midday  ...  Allerton/Pelham Gardens_10_False
# 98143        False_Morning Rush  ...                Ocean Hill_7_False
# 98137        False_Morning Rush  ...                Ocean Hill_5_False
# 98138        False_Morning Rush  ...                Ocean Hill_8_False
# 98139              False_Midday  ...               Ocean Hill_11_False
# ...                         ...  ...                               ...
# 49064              False_Midday  ...             Fresh Meadows_14_True
# 49063              False_Midday  ...            Fresh Meadows_13_False
# 49062              False_Midday  ...            Fresh Meadows_13_False
# 49061        False_Morning Rush  ...             Fresh Meadows_8_False
# 147210      False_Early Morning  ...             Yorkville West_1_True
#
#           zone_hour_holiday_interaction pickup_day_of_week is_weekend  \
# 0       Allerton/Pelham Gardens_10_True                  0      False
# 98143                Ocean Hill_7_False                  4      False
# 98137                Ocean Hill_5_False                  2      False
# 98138                Ocean Hill_8_False                  2      False
# 98139               Ocean Hill_11_False                  2      False
# ...                                 ...                ...        ...
# 49064            Fresh Meadows_14_False                  5       True
# 49063            Fresh Meadows_13_False                  4      False
# 49062            Fresh Meadows_13_False                  3      False
# 49061             Fresh Meadows_8_False                  3      False
# 147210           Yorkville West_1_False                  6       True
#
#           time_of_day  is_holiday trip_count  trip_count_1h_ago  \
# 0              Midday        True          1                0.0
# 98143    Morning Rush       False          1                1.0
# 98137    Morning Rush       False          1                1.0
# 98138    Morning Rush       False          1                1.0
# 98139          Midday       False          1                1.0
# ...               ...         ...        ...                ...
# 49064          Midday       False          1                1.0
# 49063          Midday       False          1                1.0
# 49062          Midday       False          1                1.0
# 49061    Morning Rush       False          1                1.0
# 147210  Early Morning       False          1                1.0
#
#         trip_count_2h_ago  rolling_avg_2h
# 0                     0.0             0.0
# 98143                 1.0             1.0
# 98137                 1.0             1.0
# 98138                 1.0             1.0
# 98139                 1.0             1.0
# ...                   ...             ...
# 49064                 1.0             1.0
# 49063                 1.0             1.0
# 49062                 1.0             1.0
# 49061                 1.0             1.0
# 147210                1.0             1.0
#
# [147211 rows x 22 columns]

# %% [markdown]
# #### Split test and training data

# %%
def split_by_month(df, train_months, test_months):
    """
    Splits the DataFrame into train and test sets based on month numbers.
    
    Args:
        df (pd.DataFrame): The full trip_counts DataFrame.
        train_months (list of int): e.g., [1, 2, 3]
        test_months (list of int): e.g., [4]
    
    Returns:
        train_df (pd.DataFrame), test_df (pd.DataFrame)
    """
    train_mask = df['pickup_date'].dt.month.isin(train_months)
    test_mask = df['pickup_date'].dt.month.isin(test_months)
    
    train_df = df[train_mask].copy()
    test_df = df[test_mask].copy()
    
    print(f"Train set: months {train_months} → shape: {train_df.shape}")
    print(f"Test set:  months {test_months} → shape: {test_df.shape}")
    
    return train_df, test_df

# %%
# Train 
train_df, test_df = split_by_month(trip_counts, train_months=[1, 2], test_months=[3])
# Out:
# Train set: months [1, 2, 3] → shape: (147211, 22)
# Test set:  months [4] → shape: (0, 22)

# %%
plt.hist(train_df['trip_count'], bins=50)
plt.title('Distribution of trip_count (Before Log)')
plt.xlabel('trip_count')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #### Evaluate baseline data

# %%
# Compute average trip count per (pickup_zone, pickup_hour) in January
zone_hour_avg = train_df.groupby(['pickup_zone', 'pickup_hour'])['trip_count'].mean().reset_index()
zone_hour_avg.columns = ['pickup_zone', 'pickup_hour', 'baseline_pred']

# %%
# Merge with February test set
test_df = test_df.merge(zone_hour_avg, on=['pickup_zone', 'pickup_hour'], how='left')

# %%
# Fill any missing predictions with overall January average
global_avg = train_df['trip_count'].mean()
test_df['baseline_pred'].fillna(global_avg, inplace=True)
# Out:
# /var/folders/jx/f68bh07x2yj9wm1y4w06hh040000gn/T/ipykernel_60954/3044719067.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test_df['baseline_pred'].fillna(global_avg, inplace=True)

# %%
# Evaluate the baseline
from sklearn.metrics import mean_squared_error, r2_score

rmse = mean_squared_error(test_df['trip_count'], test_df['baseline_pred'], squared=False)
r2 = r2_score(test_df['trip_count'], test_df['baseline_pred'])

print(f"Baseline RMSE: {rmse:.2f}")
print(f"Baseline R²: {r2:.2f}")
# Out:
# Baseline RMSE: 0.00
# Baseline R²: 1.00
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
# Drop baseline column after evaluation
test_df.drop(columns=['baseline_pred'], inplace=True)

# %% [markdown]
# #### Log transformation

# %%
train_df['log_trip_count'] = np.log1p(train_df['trip_count'])
test_df['log_trip_count'] = np.log1p(test_df['trip_count'])

# %%
plt.hist(train_df['log_trip_count'], bins=50)
plt.title('Distribution of trip_count (After Log)')
plt.xlabel('log_trip_count')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #### Define Target and Features

# %%
# Define target and features
target_column = 'log_trip_count'

# Step 1: Create log-transformed target columns
train_df['log_trip_count'] = np.log1p(train_df['trip_count'])
test_df['log_trip_count'] = np.log1p(test_df['trip_count'])

# Step 2: Drop raw trip_count (optional but cleaner)
X_train = train_df.drop(columns=['trip_count', target_column])
y_train = train_df[target_column]

X_test = test_df.drop(columns=['trip_count', target_column])
y_test = test_df[target_column]

# Step 3: Add log_trip_count back if needed for encoding or merging
X_train_full = X_train.copy()
X_train_full[target_column] = y_train

X_test_full = X_test.copy()
X_test_full[target_column] = y_test

# %% [markdown]
# #### Encoding

# %%
# Base encoding 
def base_encode(df):
    df_encoded = df.copy()
    df_encoded['is_weekend'] = df_encoded['is_weekend'].astype(int)
    time_order = {
        'Early Morning': 0, 'Morning Rush': 1, 'Midday': 2, 'Evening Rush': 3, 'Night': 4
    }
    df_encoded['time_of_day_encoded'] = df_encoded['time_of_day'].map(time_order)
    df_encoded.drop('time_of_day', axis=1, inplace=True)
    
    # One-hot encoding for pickup_borough and day_type
    df_encoded = pd.get_dummies(df_encoded, columns=['pickup_borough', 'day_type'], drop_first=False)
    return df_encoded

#  Target Encoding 
def target_encode_train_and_apply(train_df, test_df, target_column, zone_column):
    train_encoded = train_df.copy()
    test_encoded = test_df.copy()
    kf = KFold(n_splits=5, shuffle=True, random_state=42)

    for col in zone_column:
        new_col = f"{col}_target_encoded"
        train_encoded[new_col] = np.nan
        for train_idx, val_idx in kf.split(train_df):
            train_fold, val_fold = train_df.iloc[train_idx], train_df.iloc[val_idx]
            means = train_fold.groupby(col)[target_column].mean()
            train_encoded.loc[val_fold.index, new_col] = val_fold[col].map(means)
        final_means = train_df.groupby(col)[target_column].mean()
        test_encoded[new_col] = test_df[col].map(final_means)
        train_encoded.drop(columns=col, inplace=True)
        test_encoded.drop(columns=col, inplace=True)
    return train_encoded, test_encoded


#  Base encode the full data with target temporarily added
train_base = base_encode(X_train_full)
test_base = base_encode(X_test_full)

#  Target encode the zone columns
train_encoded, test_encoded = target_encode_train_and_apply(
    train_base, test_base,
    target_column='log_trip_count',
    zone_column=['pickup_zone', 'day_time_interaction', 'zone_hour_interaction', 'holiday_time_interaction', 'zone_isweekend_interaction', 'hour_isweekend_interaction', 'zone_time_isweekend_interaction', 'zone_hour_isweekend_interaction', 'zone_hour_holiday_interaction']
)

# %%
#  Drop datetime columns
for col in ['pickup_date', 'tpep_pickup_datetime']:
    train_encoded.drop(columns=col, errors='ignore', inplace=True)
    test_encoded.drop(columns=col, errors='ignore', inplace=True)

#  NOW drop the target from the features
X_train_final = train_encoded.drop(columns=['log_trip_count'])
X_test_final = test_encoded.drop(columns=['log_trip_count'])

# Final check
print("Final training columns:", X_train_final.columns)
# Out:
# Final training columns: Index(['pickup_hour', 'pickup_month', 'pickup_day_of_week', 'is_weekend',
#        'is_holiday', 'trip_count_1h_ago', 'trip_count_2h_ago',
#        'rolling_avg_2h', 'time_of_day_encoded', 'pickup_borough_Bronx',
#        'pickup_borough_Brooklyn', 'pickup_borough_EWR',
#        'pickup_borough_Manhattan', 'pickup_borough_Queens',
#        'pickup_borough_Staten Island', 'day_type_Weekday', 'day_type_Weekend',
#        'pickup_zone_target_encoded', 'day_time_interaction_target_encoded',
#        'zone_hour_interaction_target_encoded',
#        'holiday_time_interaction_target_encoded',
#        'zone_isweekend_interaction_target_encoded',
#        'hour_isweekend_interaction_target_encoded',
#        'zone_time_isweekend_interaction_target_encoded',
#        'zone_hour_isweekend_interaction_target_encoded',
#        'zone_hour_holiday_interaction_target_encoded'],
#       dtype='object')

# %% [markdown]
# #### Train and Evaluate Random Forrest

# %% [markdown]
# ##### Random Forrest using cv = 3

# %%
# Prepare data
X_train = train_encoded.drop(columns='log_trip_count')
y_train = train_encoded['log_trip_count']
X_test = test_encoded.drop(columns='log_trip_count')
y_test = test_encoded['log_trip_count']

# Define model
model = RandomForestRegressor(random_state=42, n_jobs=-1)

# Hyperparameter grid
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [10, 20, None],
    'max_features': ['sqrt', 'log2']
}

# Grid search
grid = GridSearchCV(
    estimator=model,
    param_grid=param_grid,
    scoring='neg_root_mean_squared_error',
    cv=3,
    verbose=1,
    n_jobs=-1
)

# Fit grid search
grid.fit(X_train, y_train)

# Best model
best_model = grid.best_estimator_
log_preds = best_model.predict(X_test)

# Inverse log transform
y_pred = np.expm1(log_preds)                   # back to trip_count
y_true = np.expm1(y_test)                      # true trip counts

# Evaluation
print("Best Parameters:", grid.best_params_)
print("Evaluation on Test Set (in original trip_count scale):")
print("RMSE:", mean_squared_error(y_true, y_pred, squared=False))
print("MAE:", mean_absolute_error(y_true, y_pred))
print("R² Score:", r2_score(y_true, y_pred))

# Plot actual vs predicted
plt.figure(figsize=(8, 5))
plt.scatter(y_true, y_pred, alpha=0.3)
plt.xlabel("Actual Trip Count")
plt.ylabel("Predicted Trip Count")
plt.title("Random Forest: Actual vs Predicted (Original Scale)")
plt.grid(True)
plt.tight_layout()
plt.show()

# Feature importance
importances = best_model.feature_importances_
features = X_train.columns
indices = np.argsort(importances)[::-1]

plt.figure(figsize=(10, 6))
plt.title("Random Forest Feature Importance (Top 15)")
plt.bar(range(15), importances[indices[:15]])
plt.xticks(range(15), [features[i] for i in indices[:15]], rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 28
#      18 grid = GridSearchCV(
#      19     estimator=model,
#      20     param_grid=param_grid,
#    (...)
#      24     n_jobs=-1
#      25 )
#      27 # Fit grid search
# ---> 28 grid.fit(X_train, y_train)
#      30 # Best model
#      31 best_model = grid.best_estimator_
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/model_selection/_search.py:970, in BaseSearchCV.fit(self, X, y, **params)
#     964     results = self._format_results(
#     965         all_candidate_params, n_splits, all_out, all_more_results
#     966     )
#     968     return results
# --> 970 self._run_search(evaluate_candidates)
#     972 # multimetric is determined here because in the case of a callable
#     973 # self.scoring the return type is only known after calling
#     974 first_test_score = all_out[0]["test_scores"]
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/model_selection/_search.py:1527, in GridSearchCV._run_search(self, evaluate_candidates)
#    1525 def _run_search(self, evaluate_candidates):
#    1526     """Search all candidates in param_grid"""
# -> 1527     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/model_selection/_search.py:947, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     940 elif len(out) != n_candidates * n_splits:
#     941     raise ValueError(
#     942         "cv.split and cv.get_n_splits returned "
#     943         "inconsistent results. Expected {} "
#     944         "splits, got {}".format(n_splits, len(out) // n_candidates)
#     945     )
# --> 947 _warn_or_raise_about_fit_failures(out, self.error_score)
#     949 # For callable self.scoring, the return type is only know after
#     950 # calling. If the return type is a dictionary, the error scores
#     951 # can now be inserted with the correct key. The type checking
#     952 # of out will be done in `_insert_error_scores`.
#     953 if callable(self.scoring):
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:536, in _warn_or_raise_about_fit_failures(results, error_score)
#     529 if num_failed_fits == num_fits:
#     530     all_fits_failed_message = (
#     531         f"\nAll the {num_fits} fits failed.\n"
#     532         "It is very likely that your model is misconfigured.\n"
#     533         "You can try to debug the error by setting error_score='raise'.\n\n"
#     534         f"Below are more details about the failures:\n{fit_errors_summary}"
#     535     )
# --> 536     raise ValueError(all_fits_failed_message)
#     538 else:
#     539     some_fits_failed_message = (
#     540         f"\n{num_failed_fits} fits failed out of a total of {num_fits}.\n"
#     541         "The score on these train-test partitions for these parameters"
#    (...)
#     545         f"Below are more details about the failures:\n{fit_errors_summary}"
#     546     )
#
# ValueError:
# All the 36 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 36 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py", line 1474, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/ensemble/_forest.py", line 363, in fit
#     X, y = self._validate_data(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py", line 650, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/validation.py", line 1263, in check_X_y
#     X = check_array(
#         ^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/validation.py", line 921, in check_array
#     array = array.astype(new_dtype)
#             ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py", line 6643, in astype
#     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/pandas/core/internals/managers.py", line 430, in astype
#     return self.apply(
#            ^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/pandas/core/internals/managers.py", line 363, in apply
#     applied = getattr(b, f)(**kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/pandas/core/internals/blocks.py", line 758, in astype
#     new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/pandas/core/dtypes/astype.py", line 237, in astype_array_safe
#     new_values = astype_array(values, dtype, copy=copy)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/pandas/core/dtypes/astype.py", line 182, in astype_array
#     values = _astype_nansafe(values, dtype, copy=copy)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/pandas/core/dtypes/astype.py", line 133, in _astype_nansafe
#     return arr.astype(dtype, copy=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ValueError: could not convert string to float: '2023-01'

# %% [markdown]
# **Evaluation:**
# | Metric       | Value | Assessment                                              |
# | ------------ | ----- | ------------------------------------------------------- |
# | **RMSE**     | 13.42 | Very low error — good predictive precision              |
# | **MAE**      | 6.40  | Strong — indicates stable performance, low average miss |
# | **R² Score** | 0.968 | Excellent — explains \~97% of variance in trip counts   |

# %% [markdown]
# ##### Random Forrest using cv = 5

# %%
# Prepare data
X_train = train_encoded.drop(columns='log_trip_count')
y_train = train_encoded['log_trip_count']
X_test = test_encoded.drop(columns='log_trip_count')
y_test = test_encoded['log_trip_count']

# Define model
model = RandomForestRegressor(random_state=42, n_jobs=-1)

# Hyperparameter grid
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [10, 20, None],
    'max_features': ['sqrt', 'log2']
}

# Grid search
grid = GridSearchCV(
    estimator=model,
    param_grid=param_grid,
    scoring='neg_root_mean_squared_error',
    cv=5,
    verbose=1,
    n_jobs=-1
)

# Fit grid search
grid.fit(X_train, y_train)

# Best model
best_model = grid.best_estimator_
log_preds = best_model.predict(X_test)

# Inverse log transform
y_pred = np.expm1(log_preds)                   # back to trip_count
y_true = np.expm1(y_test)                      # true trip counts

# Evaluation
print("Best Parameters:", grid.best_params_)
print("Evaluation on Test Set (in original trip_count scale):")
print("RMSE:", mean_squared_error(y_true, y_pred, squared=False))
print("MAE:", mean_absolute_error(y_true, y_pred))
print("R² Score:", r2_score(y_true, y_pred))

# Plot actual vs predicted
plt.figure(figsize=(8, 5))
plt.scatter(y_true, y_pred, alpha=0.3)
plt.xlabel("Actual Trip Count")
plt.ylabel("Predicted Trip Count")
plt.title("Random Forest: Actual vs Predicted (Original Scale)")
plt.grid(True)
plt.tight_layout()
plt.show()

# Feature importance
importances = best_model.feature_importances_
features = X_train.columns
indices = np.argsort(importances)[::-1]

plt.figure(figsize=(10, 6))
plt.title("Random Forest Feature Importance (Top 15)")
plt.bar(range(15), importances[indices[:15]])
plt.xticks(range(15), [features[i] for i in indices[:15]], rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### **Evaluation**
# | Metric       | Value  | Comment                                   |
# | ------------ | ------ | ----------------------------------------- |
# | **RMSE**     | 13.42  | Matches CV=3 — very low error             |
# | **MAE**      | 6.41   | Consistent with earlier model             |
# | **R² Score** | 0.9682 | Still strong — no overfitting detected |

# %% [markdown]
# | Setting | RMSE  | MAE  | R²     | Notes                     |
# | ------- | ----- | ---- | ------ | ------------------------- |
# | CV = 3  | 13.42 | 6.40 | 0.9682 | Slightly simpler (faster) |
# | CV = 5  | 13.42 | 6.41 | 0.9682 | More robust, same result  |

# %% [markdown]
# | Rank | Feature Name                                     | Description                                                            |
# | ---- | ------------------------------------------------ | ---------------------------------------------------------------------- |
# | 1    | `trip_count_1h_ago`                              | Trip demand one hour ago in the same zone - strongest temporal signal  |
# | 2    | `rolling_avg_2h`                                 | Smoothed average demand over past 2 hours                              |
# | 3    | `zone_hour_interaction_target_encoded`           | Historical demand patterns for each zone-hour combination              |
# | 4    | `zone_hour_holiday_interaction_target_encoded`   | Captures holiday-related demand deviations by zone and hour            |
# | 5    | `zone_time_isweekend_interaction_target_encoded` | Weekend-specific demand trends for zones and time-of-day               |
# | 6    | `zone_isweekend_interaction_target_encoded`      | Captures overall weekend demand shifts in each zone                    |
# | 7    | `trip_count_2h_ago`                              | Trip demand two hours ago in the same zone                             |
# | 8    | `pickup_zone_target_encoded`                     | Mean demand for the pickup zone                                        |
# | 9    | `day_time_interaction_target_encoded`            | Demand pattern for specific day/time combinations                      |
# | 10   | `zone_weekend_interaction_target_encoded`        | General weekend vs. weekday pattern by zone                            |
# | 11   | `pickup_hour`                                    | Hour of the day (raw value - less useful than interactions)            |
# | 12   | `pickup_borough_Manhattan`                       | Whether pickup is in Manhattan (low standalone value)                  |
# | 13   | `holiday_time_interaction_target_encoded`        | Holiday × time pattern (limited marginal contribution)                 |
# | 14   | `time_of_day_encoded`                            | Time-of-day category (e.g., rush hour, evening - low compared to lags) |
# | 15   | `pickup_day_of_week`                             | Weekday index (least important, likely absorbed by other interactions) |

# %% [markdown]
# #### Train and Evaluate XGBoost

# %%
from xgboost import plot_importance
# Prepare data
X_train = train_encoded.drop(columns='log_trip_count')
y_train = train_encoded['log_trip_count']
X_test = test_encoded.drop(columns='log_trip_count')
y_test = test_encoded['log_trip_count']

# Define XGBoost regression model
model = XGBRegressor(
    objective='reg:squarederror',
    eval_metric='rmse',
    verbosity=0,
    random_state=42
)

# Hyperparameter grid
param_grid = {
    'learning_rate': [0.01, 0.05, 0.1],
    'max_depth': [3, 5, 7],
    'n_estimators': [100, 200]
}

# Grid search
grid = GridSearchCV(
    estimator=model,
    param_grid=param_grid,
    scoring='neg_root_mean_squared_error',
    cv=3,
    verbose=1,
    n_jobs=-1
)

# Fit grid search
grid.fit(X_train, y_train)

# Best model
best_model = grid.best_estimator_

# Predict (in log space)
log_preds = best_model.predict(X_test)

# Convert predictions and true labels back to original scale
y_pred = np.expm1(log_preds)
y_true = np.expm1(y_test)

# Evaluation
print("Best Parameters:", grid.best_params_)
print("Evaluation on Test Set (Original Scale):")
print("RMSE:", mean_squared_error(y_true, y_pred, squared=False))
print("MAE:", mean_absolute_error(y_true, y_pred))
print("R² Score:", r2_score(y_true, y_pred))

# Plot actual vs predicted (in original scale)
plt.figure(figsize=(8, 5))
plt.scatter(y_true, y_pred, alpha=0.3)
plt.xlabel("Actual Trip Count")
plt.ylabel("Predicted Trip Count")
plt.title("XGBoost: Actual vs Predicted (Original Scale)")
plt.grid(True)
plt.tight_layout()
plt.show()

# Feature importance
plot_importance(best_model, max_num_features=15, importance_type='gain')
plt.title("XGBoost Feature Importance (Top 15)")
plt.tight_layout()
plt.show()

# %%
# Prepare data (already encoded)
X_train = train_encoded.drop(columns='log_trip_count')
y_train = train_encoded['log_trip_count']
X_test = test_encoded.drop(columns='log_trip_count')
y_test = test_encoded['log_trip_count']

# Define XGBoost model
model = XGBRegressor(
    objective='reg:squarederror',
    eval_metric='rmse',
    verbosity=0,
    random_state=42
)

# Hyperparameter grid
param_grid = {
    'learning_rate': [0.01, 0.05, 0.1],
    'max_depth': [3, 5, 7],
    'n_estimators': [100, 200]
}

# Grid search
grid = GridSearchCV(
    estimator=model,
    param_grid=param_grid,
    scoring='neg_root_mean_squared_error',
    cv=3,
    verbose=1,
    n_jobs=-1
)

# Fit
grid.fit(X_train, y_train)

# Best model
best_model = grid.best_estimator_
log_preds = best_model.predict(X_test)

# Inverse log-transform
y_pred = np.expm1(log_preds)
y_true = np.expm1(y_test)

# Evaluation
print("Best Parameters:", grid.best_params_)
print("Evaluation on Test Set (Original Scale):")
print("RMSE:", mean_squared_error(y_true, y_pred, squared=False))
print("MAE:", mean_absolute_error(y_true, y_pred))
print("R² Score:", r2_score(y_true, y_pred))

# Absolute error
errors = np.abs(y_true - y_pred)

# Scatter plot colored by absolute error
plt.figure(figsize=(8, 6))
scatter = plt.scatter(
    y_true, y_pred,
    c=errors,
    cmap='coolwarm',
    alpha=0.6,
    edgecolor='k'
)
plt.xlabel("Actual Trip Count")
plt.ylabel("Predicted Trip Count")
plt.title("XGBoost: Actual vs Predicted (Colored by Absolute Error)")
plt.colorbar(scatter, label='Absolute Error')
plt.grid(True)
plt.tight_layout()
plt.show()

# Feature importance
plot_importance(best_model, max_num_features=15, importance_type='gain')
plt.title("XGBoost Feature Importance (Top 15)")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Train and Evaluate LightGBM

# %%
from lightgbm import plot_importance
# Prepare data
X_train = train_encoded.drop(columns='log_trip_count')
y_train = train_encoded['log_trip_count']
X_test = test_encoded.drop(columns='log_trip_count')
y_test = test_encoded['log_trip_count']

# Define LightGBM regression model
model = LGBMRegressor(
    objective='regression',
    verbosity=-1,
    random_state=42
)

# Hyperparameter grid
param_grid = {
    'learning_rate': [0.01, 0.05, 0.1],
    'max_depth': [3, 5, 7],
    'n_estimators': [100, 200]
}

# Grid search
grid = GridSearchCV(
    estimator=model,
    param_grid=param_grid,
    scoring='neg_root_mean_squared_error',
    cv=3,
    verbose=1,
    n_jobs=-1
)

# Fit grid search
grid.fit(X_train, y_train)

# Best model
best_model = grid.best_estimator_
log_preds = best_model.predict(X_test)

# Inverse log-transform
y_pred = np.expm1(log_preds)
y_true = np.expm1(y_test)

# Evaluation
print("Best Parameters:", grid.best_params_)
print("Evaluation on Test Set (Original Scale):")
print("RMSE:", mean_squared_error(y_true, y_pred, squared=False))
print("MAE:", mean_absolute_error(y_true, y_pred))
print("R² Score:", r2_score(y_true, y_pred))

# Plot actual vs predicted
plt.figure(figsize=(8, 5))
plt.scatter(y_true, y_pred, alpha=0.3)
plt.xlabel("Actual Trip Count")
plt.ylabel("Predicted Trip Count")
plt.title("LightGBM: Actual vs Predicted (Original Scale)")
plt.grid(True)
plt.tight_layout()
plt.show()

# Feature importance
plt.figure(figsize=(8, 6))
plot_importance(best_model.booster_, max_num_features=15, importance_type='gain')
plt.title("LightGBM Feature Importance (Top 15)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### **Evaluation (Conclusion)**
# - All models achieve high accuracy, explaining over 96% of variance in trip demand.
# - Random Forest relies more on raw temporal signals, while boosting models learn from encoded interaction patterns.
# - The consistency across models confirms that both recent demand and zone-hour context are key predictors of taxi activity.
