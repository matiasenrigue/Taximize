# %%
import pandas as pd
import geopandas as gpd
import os
import osmnx as ox
from shapely.geometry import Polygon

# %%
# Load NYC taxi zones shapefile
gdf = gpd.read_file("taxi_zones.shp")

# Ensure geometry is valid and projected
gdf = gdf.to_crs("EPSG:4326")  # WGS84 for OSMnx

# %%
# Define nightlife POI tags
tags = {
    "amenity": ["bar", "pub", "nightclub"]
}

# Loop through each zone and fetch nightlife POIs 
all_nightlife = []

for idx, row in gdf.iterrows():
    zone_name = row["zone"]
    geom = row["geometry"]

    try:
        pois = ox.features_from_polygon(geom, tags) # Used to query OSM for POIs within the zone geometry
        pois["zone"] = zone_name
        all_nightlife.append(pois)
        print(f"{zone_name}: {len(pois)} nightlife POIs")
    except Exception as e:
        print(f"{zone_name} failed: {e}")

# Combine all nightlife POIs
nightlife_all = pd.concat(all_nightlife, ignore_index=True)

# Convert to GeoDataFrame and reproject for area calc
nightlife_gdf = gpd.GeoDataFrame(nightlife_all, geometry="geometry", crs="EPSG:4326").to_crs("EPSG:2263")
zones_proj = gdf.to_crs("EPSG:2263")
# Out:
# Newark Airport: 9 nightlife POIs
# Jamaica Bay failed: No matching features. Check query location, tags, and log.
# Allerton/Pelham Gardens: 1 nightlife POIs
# Alphabet City: 11 nightlife POIs
# Arden Heights failed: No matching features. Check query location, tags, and log.
# Arrochar/Fort Wadsworth failed: No matching features. Check query location, tags, and log.
# Astoria: 53 nightlife POIs
# Astoria Park failed: No matching features. Check query location, tags, and log.
# Auburndale: 2 nightlife POIs
# Baisley Park: 2 nightlife POIs
# Bath Beach failed: No matching features. Check query location, tags, and log.
# Battery Park failed: No matching features. Check query location, tags, and log.
# Battery Park City: 3 nightlife POIs
# Bay Ridge: 20 nightlife POIs
# Bay Terrace/Fort Totten failed: No matching features. Check query location, tags, and log.
# Bayside: 2 nightlife POIs
# Bedford: 17 nightlife POIs
# Bedford Park: 1 nightlife POIs
# Bellerose: 1 nightlife POIs
# Belmont: 1 nightlife POIs
# Bensonhurst East failed: No matching features. Check query location, tags, and log.
# Bensonhurst West failed: No matching features. Check query location, tags, and log.
# Bloomfield/Emerson Hill: 1 nightlife POIs
# Bloomingdale: 5 nightlife POIs
# Boerum Hill: 24 nightlife POIs
# Borough Park: 1 nightlife POIs
# Breezy Point/Fort Tilden/Riis Beach: 1 nightlife POIs
# Briarwood/Jamaica Hills: 2 nightlife POIs
# Brighton Beach: 2 nightlife POIs
# Broad Channel failed: No matching features. Check query location, tags, and log.
# Bronx Park failed: No matching features. Check query location, tags, and log.
# Bronxdale failed: No matching features. Check query location, tags, and log.
# Brooklyn Heights: 7 nightlife POIs
# Brooklyn Navy Yard: 3 nightlife POIs
# Brownsville: 1 nightlife POIs
# Bushwick North: 54 nightlife POIs
# Bushwick South: 48 nightlife POIs
# Cambria Heights failed: No matching features. Check query location, tags, and log.
# Canarsie failed: No matching features. Check query location, tags, and log.
# Carroll Gardens: 16 nightlife POIs
# Central Harlem: 4 nightlife POIs
# Central Harlem North: 3 nightlife POIs
# Central Park: 2 nightlife POIs
# Charleston/Tottenville: 2 nightlife POIs
# Chinatown: 7 nightlife POIs
# City Island: 3 nightlife POIs
# Claremont/Bathgate: 1 nightlife POIs
# Clinton East: 42 nightlife POIs
# Clinton Hill: 25 nightlife POIs
# Clinton West: 10 nightlife POIs
# Co-Op City failed: No matching features. Check query location, tags, and log.
# Cobble Hill: 5 nightlife POIs
# College Point: 1 nightlife POIs
# Columbia Street: 3 nightlife POIs
# Coney Island: 5 nightlife POIs
# Corona failed: No matching features. Check query location, tags, and log.
# Corona: 1 nightlife POIs
# Country Club failed: No matching features. Check query location, tags, and log.
# Crotona Park failed: No matching features. Check query location, tags, and log.
# Crotona Park East failed: No matching features. Check query location, tags, and log.
# Crown Heights North: 21 nightlife POIs
# Crown Heights South: 4 nightlife POIs
# Cypress Hills failed: No matching features. Check query location, tags, and log.
# Douglaston failed: No matching features. Check query location, tags, and log.
# Downtown Brooklyn/MetroTech: 6 nightlife POIs
# DUMBO/Vinegar Hill: 6 nightlife POIs
# Dyker Heights failed: No matching features. Check query location, tags, and log.
# East Chelsea: 22 nightlife POIs
# East Concourse/Concourse Village: 1 nightlife POIs
# East Elmhurst: 1 nightlife POIs
# East Flatbush/Farragut: 1 nightlife POIs
# East Flatbush/Remsen Village failed: No matching features. Check query location, tags, and log.
# East Flushing: 1 nightlife POIs
# East Harlem North: 1 nightlife POIs
# East Harlem South: 6 nightlife POIs
# East New York failed: No matching features. Check query location, tags, and log.
# East New York/Pennsylvania Avenue failed: No matching features. Check query location, tags, and log.
# East Tremont failed: No matching features. Check query location, tags, and log.
# East Village: 121 nightlife POIs
# East Williamsburg: 37 nightlife POIs
# Eastchester failed: No matching features. Check query location, tags, and log.
# Elmhurst: 10 nightlife POIs
# Elmhurst/Maspeth: 1 nightlife POIs
# Eltingville/Annadale/Prince's Bay failed: No matching features. Check query location, tags, and log.
# Erasmus: 1 nightlife POIs
# Far Rockaway failed: No matching features. Check query location, tags, and log.
# Financial District North: 12 nightlife POIs
# Financial District South: 9 nightlife POIs
# Flatbush/Ditmas Park: 6 nightlife POIs
# Flatiron: 14 nightlife POIs
# Flatlands: 1 nightlife POIs
# Flushing: 4 nightlife POIs
# Flushing Meadows-Corona Park: 5 nightlife POIs
# Fordham South failed: No matching features. Check query location, tags, and log.
# Forest Hills: 5 nightlife POIs
# Forest Park/Highland Park failed: No matching features. Check query location, tags, and log.
# Fort Greene: 16 nightlife POIs
# Fresh Meadows: 1 nightlife POIs
# Freshkills Park: 2 nightlife POIs
# Garment District: 16 nightlife POIs
# Glen Oaks: 3 nightlife POIs
# Glendale: 3 nightlife POIs
# Governor's Island/Ellis Island/Liberty Island failed: No matching features. Check query location, tags, and log.
# Governor's Island/Ellis Island/Liberty Island failed: No matching features. Check query location, tags, and log.
# Governor's Island/Ellis Island/Liberty Island: 2 nightlife POIs
# Gowanus: 14 nightlife POIs
# Gramercy: 28 nightlife POIs
# Gravesend: 2 nightlife POIs
# Great Kills: 5 nightlife POIs
# Great Kills Park failed: No matching features. Check query location, tags, and log.
# Green-Wood Cemetery failed: No matching features. Check query location, tags, and log.
# Greenpoint: 50 nightlife POIs
# Greenwich Village North: 9 nightlife POIs
# Greenwich Village South: 43 nightlife POIs
# Grymes Hill/Clifton failed: No matching features. Check query location, tags, and log.
# Hamilton Heights: 1 nightlife POIs
# Hammels/Arverne: 4 nightlife POIs
# Heartland Village/Todt Hill: 1 nightlife POIs
# Highbridge: 1 nightlife POIs
# Highbridge Park failed: No matching features. Check query location, tags, and log.
# Hillcrest/Pomonok failed: No matching features. Check query location, tags, and log.
# Hollis: 1 nightlife POIs
# Homecrest failed: No matching features. Check query location, tags, and log.
# Howard Beach failed: No matching features. Check query location, tags, and log.
# Hudson Sq: 2 nightlife POIs
# Hunts Point failed: No matching features. Check query location, tags, and log.
# Inwood: 5 nightlife POIs
# Inwood Hill Park failed: No matching features. Check query location, tags, and log.
# Jackson Heights: 10 nightlife POIs
# Jamaica: 11 nightlife POIs
# Jamaica Estates: 1 nightlife POIs
# JFK Airport: 13 nightlife POIs
# Kensington: 2 nightlife POIs
# Kew Gardens: 2 nightlife POIs
# Kew Gardens Hills: 2 nightlife POIs
# Kingsbridge Heights failed: No matching features. Check query location, tags, and log.
# Kips Bay: 8 nightlife POIs
# LaGuardia Airport: 9 nightlife POIs
# Laurelton: 2 nightlife POIs
# Lenox Hill East: 7 nightlife POIs
# Lenox Hill West: 17 nightlife POIs
# Lincoln Square East: 10 nightlife POIs
# Lincoln Square West: 3 nightlife POIs
# Little Italy/NoLiTa: 18 nightlife POIs
# Long Island City/Hunters Point: 17 nightlife POIs
# Long Island City/Queens Plaza: 5 nightlife POIs
# Longwood failed: No matching features. Check query location, tags, and log.
# Lower East Side: 70 nightlife POIs
# Madison failed: No matching features. Check query location, tags, and log.
# Manhattan Beach: 1 nightlife POIs
# Manhattan Valley: 4 nightlife POIs
# Manhattanville: 2 nightlife POIs
# Marble Hill failed: No matching features. Check query location, tags, and log.
# Marine Park/Floyd Bennett Field failed: No matching features. Check query location, tags, and log.
# Marine Park/Mill Basin failed: No matching features. Check query location, tags, and log.
# Mariners Harbor: 1 nightlife POIs
# Maspeth: 9 nightlife POIs
# Meatpacking/West Village West: 16 nightlife POIs
# Melrose South failed: No matching features. Check query location, tags, and log.
# Middle Village: 4 nightlife POIs
# Midtown Center: 21 nightlife POIs
# Midtown East: 7 nightlife POIs
# Midtown North: 10 nightlife POIs
# Midtown South: 24 nightlife POIs
# Midwood failed: No matching features. Check query location, tags, and log.
# Morningside Heights: 5 nightlife POIs
# Morrisania/Melrose: 1 nightlife POIs
# Mott Haven/Port Morris: 2 nightlife POIs
# Mount Hope failed: No matching features. Check query location, tags, and log.
# Murray Hill: 16 nightlife POIs
# Murray Hill-Queens failed: No matching features. Check query location, tags, and log.
# New Dorp/Midland Beach failed: No matching features. Check query location, tags, and log.
# North Corona: 2 nightlife POIs
# Norwood failed: No matching features. Check query location, tags, and log.
# Oakland Gardens: 1 nightlife POIs
# Oakwood failed: No matching features. Check query location, tags, and log.
# Ocean Hill: 1 nightlife POIs
# Ocean Parkway South failed: No matching features. Check query location, tags, and log.
# Old Astoria: 3 nightlife POIs
# Ozone Park: 1 nightlife POIs
# Park Slope: 46 nightlife POIs
# Parkchester: 1 nightlife POIs
# Pelham Bay: 1 nightlife POIs
# Pelham Bay Park failed: No matching features. Check query location, tags, and log.
# Pelham Parkway failed: No matching features. Check query location, tags, and log.
# Penn Station/Madison Sq West: 15 nightlife POIs
# Port Richmond: 1 nightlife POIs
# Prospect-Lefferts Gardens: 9 nightlife POIs
# Prospect Heights: 22 nightlife POIs
# Prospect Park failed: No matching features. Check query location, tags, and log.
# Queens Village failed: No matching features. Check query location, tags, and log.
# Queensboro Hill: 1 nightlife POIs
# Queensbridge/Ravenswood failed: No matching features. Check query location, tags, and log.
# Randalls Island failed: No matching features. Check query location, tags, and log.
# Red Hook: 11 nightlife POIs
# Rego Park failed: No matching features. Check query location, tags, and log.
# Richmond Hill: 4 nightlife POIs
# Ridgewood: 33 nightlife POIs
# Rikers Island failed: No matching features. Check query location, tags, and log.
# Riverdale/North Riverdale/Fieldston: 1 nightlife POIs
# Rockaway Park: 5 nightlife POIs
# Roosevelt Island: 1 nightlife POIs
# Rosedale failed: No matching features. Check query location, tags, and log.
# Rossville/Woodrow: 1 nightlife POIs
# Saint Albans: 3 nightlife POIs
# Saint George/New Brighton: 4 nightlife POIs
# Saint Michaels Cemetery/Woodside failed: No matching features. Check query location, tags, and log.
# Schuylerville/Edgewater Park failed: No matching features. Check query location, tags, and log.
# Seaport: 4 nightlife POIs
# Sheepshead Bay: 4 nightlife POIs
# SoHo: 8 nightlife POIs
# Soundview/Bruckner: 2 nightlife POIs
# Soundview/Castle Hill failed: No matching features. Check query location, tags, and log.
# South Beach/Dongan Hills failed: No matching features. Check query location, tags, and log.
# South Jamaica: 1 nightlife POIs
# South Ozone Park: 6 nightlife POIs
# South Williamsburg failed: No matching features. Check query location, tags, and log.
# Springfield Gardens North failed: No matching features. Check query location, tags, and log.
# Springfield Gardens South failed: No matching features. Check query location, tags, and log.
# Spuyten Duyvil/Kingsbridge: 3 nightlife POIs
# Stapleton: 4 nightlife POIs
# Starrett City failed: No matching features. Check query location, tags, and log.
# Steinway: 22 nightlife POIs
# Stuy Town/Peter Cooper Village failed: No matching features. Check query location, tags, and log.
# Stuyvesant Heights: 14 nightlife POIs
# Sunnyside: 20 nightlife POIs
# Sunset Park East: 4 nightlife POIs
# Sunset Park West: 22 nightlife POIs
# Sutton Place/Turtle Bay North: 11 nightlife POIs
# Times Sq/Theatre District: 25 nightlife POIs
# TriBeCa/Civic Center: 20 nightlife POIs
# Two Bridges/Seward Park: 6 nightlife POIs
# UN/Turtle Bay South: 5 nightlife POIs
# Union Sq: 30 nightlife POIs
# University Heights/Morris Heights failed: No matching features. Check query location, tags, and log.
# Upper East Side North: 6 nightlife POIs
# Upper East Side South: 2 nightlife POIs
# Upper West Side North: 5 nightlife POIs
# Upper West Side South: 20 nightlife POIs
# Van Cortlandt Park failed: No matching features. Check query location, tags, and log.
# Van Cortlandt Village failed: No matching features. Check query location, tags, and log.
# Van Nest/Morris Park: 2 nightlife POIs
# Washington Heights North: 6 nightlife POIs
# Washington Heights South: 2 nightlife POIs
# West Brighton failed: No matching features. Check query location, tags, and log.
# West Chelsea/Hudson Yards: 10 nightlife POIs
# West Concourse: 2 nightlife POIs
# West Farms/Bronx River failed: No matching features. Check query location, tags, and log.
# West Village: 34 nightlife POIs
# Westchester Village/Unionport failed: No matching features. Check query location, tags, and log.
# Westerleigh: 2 nightlife POIs
# Whitestone: 1 nightlife POIs
# Willets Point failed: No matching features. Check query location, tags, and log.
# Williamsbridge/Olinville failed: No matching features. Check query location, tags, and log.
# Williamsburg (North Side): 42 nightlife POIs
# Williamsburg (South Side): 39 nightlife POIs
# Windsor Terrace: 5 nightlife POIs
# Woodhaven: 2 nightlife POIs
# Woodlawn/Wakefield: 6 nightlife POIs
# Woodside: 22 nightlife POIs
# World Trade Center: 3 nightlife POIs
# Yorkville East: 4 nightlife POIs
# Yorkville West: 18 nightlife POIs

# %%
# Define major transit POI tags only 
tags = {
    "railway": ["station"],
    "amenity": ["bus_station", "ferry_terminal"],
    "aeroway": ["terminal"]  # airports
}

# Loop through each taxi zone and fetch filtered POIs
all_transit = []

for idx, row in gdf.iterrows():
    zone_name = row["zone"]
    geom = row["geometry"]

    try:
        pois = ox.features_from_polygon(geom, tags)
        pois["zone"] = zone_name
        all_transit.append(pois)
        print(f"{zone_name}: {len(pois)} major transit POIs")
    except Exception as e:
        print(f"{zone_name} failed: {e}")

# Combine and convert to GeoDataFrame 
transit_all = pd.concat(all_transit, ignore_index=True)
transit_gdf = gpd.GeoDataFrame(transit_all, geometry="geometry", crs="EPSG:4326").to_crs("EPSG:2263")
# Out:
# Newark Airport: 13 major transit POIs
# Jamaica Bay failed: No matching features. Check query location, tags, and log.
# Allerton/Pelham Gardens: 2 major transit POIs
# Alphabet City failed: No matching features. Check query location, tags, and log.
# Arden Heights failed: No matching features. Check query location, tags, and log.
# Arrochar/Fort Wadsworth: 1 major transit POIs
# Astoria: 4 major transit POIs
# Astoria Park failed: No matching features. Check query location, tags, and log.
# Auburndale: 1 major transit POIs
# Baisley Park failed: No matching features. Check query location, tags, and log.
# Bath Beach failed: No matching features. Check query location, tags, and log.
# Battery Park: 3 major transit POIs
# Battery Park City failed: No matching features. Check query location, tags, and log.
# Bay Ridge: 4 major transit POIs
# Bay Terrace/Fort Totten failed: No matching features. Check query location, tags, and log.
# Bayside: 1 major transit POIs
# Bedford: 4 major transit POIs
# Bedford Park: 4 major transit POIs
# Bellerose failed: No matching features. Check query location, tags, and log.
# Belmont: 2 major transit POIs
# Bensonhurst East: 4 major transit POIs
# Bensonhurst West: 9 major transit POIs
# Bloomfield/Emerson Hill failed: No matching features. Check query location, tags, and log.
# Bloomingdale failed: No matching features. Check query location, tags, and log.
# Boerum Hill: 4 major transit POIs
# Borough Park: 4 major transit POIs
# Breezy Point/Fort Tilden/Riis Beach failed: No matching features. Check query location, tags, and log.
# Briarwood/Jamaica Hills: 1 major transit POIs
# Brighton Beach: 2 major transit POIs
# Broad Channel: 1 major transit POIs
# Bronx Park: 1 major transit POIs
# Bronxdale: 2 major transit POIs
# Brooklyn Heights: 3 major transit POIs
# Brooklyn Navy Yard failed: No matching features. Check query location, tags, and log.
# Brownsville: 6 major transit POIs
# Bushwick North: 6 major transit POIs
# Bushwick South: 6 major transit POIs
# Cambria Heights failed: No matching features. Check query location, tags, and log.
# Canarsie: 1 major transit POIs
# Carroll Gardens: 1 major transit POIs
# Central Harlem: 5 major transit POIs
# Central Harlem North: 4 major transit POIs
# Central Park: 1 major transit POIs
# Charleston/Tottenville: 4 major transit POIs
# Chinatown: 1 major transit POIs
# City Island: 2 major transit POIs
# Claremont/Bathgate: 1 major transit POIs
# Clinton East: 2 major transit POIs
# Clinton Hill: 5 major transit POIs
# Clinton West: 1 major transit POIs
# Co-Op City: 1 major transit POIs
# Cobble Hill failed: No matching features. Check query location, tags, and log.
# College Point failed: No matching features. Check query location, tags, and log.
# Columbia Street failed: No matching features. Check query location, tags, and log.
# Coney Island: 3 major transit POIs
# Corona failed: No matching features. Check query location, tags, and log.
# Corona failed: No matching features. Check query location, tags, and log.
# Country Club failed: No matching features. Check query location, tags, and log.
# Crotona Park failed: No matching features. Check query location, tags, and log.
# Crotona Park East: 1 major transit POIs
# Crown Heights North: 7 major transit POIs
# Crown Heights South: 3 major transit POIs
# Cypress Hills: 7 major transit POIs
# Douglaston: 2 major transit POIs
# Downtown Brooklyn/MetroTech: 4 major transit POIs
# DUMBO/Vinegar Hill: 1 major transit POIs
# Dyker Heights failed: No matching features. Check query location, tags, and log.
# East Chelsea: 3 major transit POIs
# East Concourse/Concourse Village: 3 major transit POIs
# East Elmhurst failed: No matching features. Check query location, tags, and log.
# East Flatbush/Farragut: 1 major transit POIs
# East Flatbush/Remsen Village failed: No matching features. Check query location, tags, and log.
# East Flushing failed: No matching features. Check query location, tags, and log.
# East Harlem North: 4 major transit POIs
# East Harlem South: 4 major transit POIs
# East New York: 9 major transit POIs
# East New York/Pennsylvania Avenue: 3 major transit POIs
# East Tremont: 2 major transit POIs
# East Village: 2 major transit POIs
# East Williamsburg: 3 major transit POIs
# Eastchester: 1 major transit POIs
# Elmhurst: 5 major transit POIs
# Elmhurst/Maspeth failed: No matching features. Check query location, tags, and log.
# Eltingville/Annadale/Prince's Bay: 5 major transit POIs
# Erasmus: 2 major transit POIs
# Far Rockaway: 2 major transit POIs
# Financial District North: 5 major transit POIs
# Financial District South: 8 major transit POIs
# Flatbush/Ditmas Park: 6 major transit POIs
# Flatiron: 6 major transit POIs
# Flatlands failed: No matching features. Check query location, tags, and log.
# Flushing: 2 major transit POIs
# Flushing Meadows-Corona Park: 3 major transit POIs
# Fordham South: 2 major transit POIs
# Forest Hills: 4 major transit POIs
# Forest Park/Highland Park failed: No matching features. Check query location, tags, and log.
# Fort Greene: 6 major transit POIs
# Fresh Meadows failed: No matching features. Check query location, tags, and log.
# Freshkills Park failed: No matching features. Check query location, tags, and log.
# Garment District: 5 major transit POIs
# Glen Oaks failed: No matching features. Check query location, tags, and log.
# Glendale failed: No matching features. Check query location, tags, and log.
# Governor's Island/Ellis Island/Liberty Island: 2 major transit POIs
# Governor's Island/Ellis Island/Liberty Island: 1 major transit POIs
# Governor's Island/Ellis Island/Liberty Island: 3 major transit POIs
# Gowanus: 3 major transit POIs
# Gramercy: 2 major transit POIs
# Gravesend: 4 major transit POIs
# Great Kills: 2 major transit POIs
# Great Kills Park failed: No matching features. Check query location, tags, and log.
# Green-Wood Cemetery failed: No matching features. Check query location, tags, and log.
# Greenpoint: 2 major transit POIs
# Greenwich Village North: 4 major transit POIs
# Greenwich Village South: 3 major transit POIs
# Grymes Hill/Clifton failed: No matching features. Check query location, tags, and log.
# Hamilton Heights: 2 major transit POIs
# Hammels/Arverne: 6 major transit POIs
# Heartland Village/Todt Hill failed: No matching features. Check query location, tags, and log.
# Highbridge failed: No matching features. Check query location, tags, and log.
# Highbridge Park failed: No matching features. Check query location, tags, and log.
# Hillcrest/Pomonok failed: No matching features. Check query location, tags, and log.
# Hollis: 1 major transit POIs
# Homecrest: 1 major transit POIs
# Howard Beach failed: No matching features. Check query location, tags, and log.
# Hudson Sq: 2 major transit POIs
# Hunts Point: 3 major transit POIs
# Inwood: 3 major transit POIs
# Inwood Hill Park failed: No matching features. Check query location, tags, and log.
# Jackson Heights: 4 major transit POIs
# Jamaica: 8 major transit POIs
# Jamaica Estates failed: No matching features. Check query location, tags, and log.
# JFK Airport: 18 major transit POIs
# Kensington: 2 major transit POIs
# Kew Gardens: 3 major transit POIs
# Kew Gardens Hills failed: No matching features. Check query location, tags, and log.
# Kingsbridge Heights: 1 major transit POIs
# Kips Bay: 1 major transit POIs
# LaGuardia Airport: 10 major transit POIs
# Laurelton: 1 major transit POIs
# Lenox Hill East failed: No matching features. Check query location, tags, and log.
# Lenox Hill West: 1 major transit POIs
# Lincoln Square East: 4 major transit POIs
# Lincoln Square West: 1 major transit POIs
# Little Italy/NoLiTa: 5 major transit POIs
# Long Island City/Hunters Point: 10 major transit POIs
# Long Island City/Queens Plaza: 4 major transit POIs
# Longwood: 2 major transit POIs
# Lower East Side: 9 major transit POIs
# Madison: 2 major transit POIs
# Manhattan Beach failed: No matching features. Check query location, tags, and log.
# Manhattan Valley: 2 major transit POIs
# Manhattanville: 3 major transit POIs
# Marble Hill: 2 major transit POIs
# Marine Park/Floyd Bennett Field failed: No matching features. Check query location, tags, and log.
# Marine Park/Mill Basin failed: No matching features. Check query location, tags, and log.
# Mariners Harbor failed: No matching features. Check query location, tags, and log.
# Maspeth failed: No matching features. Check query location, tags, and log.
# Meatpacking/West Village West: 1 major transit POIs
# Melrose South: 2 major transit POIs
# Middle Village failed: No matching features. Check query location, tags, and log.
# Midtown Center: 2 major transit POIs
# Midtown East: 5 major transit POIs
# Midtown North: 2 major transit POIs
# Midtown South: 2 major transit POIs
# Midwood: 3 major transit POIs
# Morningside Heights: 3 major transit POIs
# Morrisania/Melrose: 1 major transit POIs
# Mott Haven/Port Morris: 7 major transit POIs
# Mount Hope: 4 major transit POIs
# Murray Hill: 1 major transit POIs
# Murray Hill-Queens: 2 major transit POIs
# New Dorp/Midland Beach: 3 major transit POIs
# North Corona: 2 major transit POIs
# Norwood: 4 major transit POIs
# Oakland Gardens failed: No matching features. Check query location, tags, and log.
# Oakwood: 2 major transit POIs
# Ocean Hill: 6 major transit POIs
# Ocean Parkway South: 3 major transit POIs
# Old Astoria failed: No matching features. Check query location, tags, and log.
# Ozone Park: 5 major transit POIs
# Park Slope: 6 major transit POIs
# Parkchester failed: No matching features. Check query location, tags, and log.
# Pelham Bay: 3 major transit POIs
# Pelham Bay Park failed: No matching features. Check query location, tags, and log.
# Pelham Parkway: 2 major transit POIs
# Penn Station/Madison Sq West: 5 major transit POIs
# Port Richmond failed: No matching features. Check query location, tags, and log.
# Prospect-Lefferts Gardens: 4 major transit POIs
# Prospect Heights: 1 major transit POIs
# Prospect Park: 1 major transit POIs
# Queens Village: 2 major transit POIs
# Queensboro Hill failed: No matching features. Check query location, tags, and log.
# Queensbridge/Ravenswood: 1 major transit POIs
# Randalls Island failed: No matching features. Check query location, tags, and log.
# Red Hook: 1 major transit POIs
# Rego Park: 1 major transit POIs
# Richmond Hill: 4 major transit POIs
# Ridgewood: 5 major transit POIs
# Rikers Island failed: No matching features. Check query location, tags, and log.
# Riverdale/North Riverdale/Fieldston: 1 major transit POIs
# Rockaway Park: 3 major transit POIs
# Roosevelt Island: 1 major transit POIs
# Rosedale: 1 major transit POIs
# Rossville/Woodrow failed: No matching features. Check query location, tags, and log.
# Saint Albans: 2 major transit POIs
# Saint George/New Brighton: 5 major transit POIs
# Saint Michaels Cemetery/Woodside failed: No matching features. Check query location, tags, and log.
# Schuylerville/Edgewater Park failed: No matching features. Check query location, tags, and log.
# Seaport: 2 major transit POIs
# Sheepshead Bay: 2 major transit POIs
# SoHo: 3 major transit POIs
# Soundview/Bruckner: 3 major transit POIs
# Soundview/Castle Hill failed: No matching features. Check query location, tags, and log.
# South Beach/Dongan Hills: 2 major transit POIs
# South Jamaica failed: No matching features. Check query location, tags, and log.
# South Ozone Park: 2 major transit POIs
# South Williamsburg: 2 major transit POIs
# Springfield Gardens North failed: No matching features. Check query location, tags, and log.
# Springfield Gardens South failed: No matching features. Check query location, tags, and log.
# Spuyten Duyvil/Kingsbridge: 4 major transit POIs
# Stapleton: 3 major transit POIs
# Starrett City failed: No matching features. Check query location, tags, and log.
# Steinway: 2 major transit POIs
# Stuy Town/Peter Cooper Village failed: No matching features. Check query location, tags, and log.
# Stuyvesant Heights: 3 major transit POIs
# Sunnyside: 4 major transit POIs
# Sunset Park East: 3 major transit POIs
# Sunset Park West: 5 major transit POIs
# Sutton Place/Turtle Bay North failed: No matching features. Check query location, tags, and log.
# Times Sq/Theatre District: 6 major transit POIs
# TriBeCa/Civic Center: 8 major transit POIs
# Two Bridges/Seward Park: 1 major transit POIs
# UN/Turtle Bay South failed: No matching features. Check query location, tags, and log.
# Union Sq: 7 major transit POIs
# University Heights/Morris Heights: 3 major transit POIs
# Upper East Side North: 3 major transit POIs
# Upper East Side South: 4 major transit POIs
# Upper West Side North: 4 major transit POIs
# Upper West Side South: 2 major transit POIs
# Van Cortlandt Park failed: No matching features. Check query location, tags, and log.
# Van Cortlandt Village: 1 major transit POIs
# Van Nest/Morris Park: 2 major transit POIs
# Washington Heights North: 6 major transit POIs
# Washington Heights South: 7 major transit POIs
# West Brighton failed: No matching features. Check query location, tags, and log.
# West Chelsea/Hudson Yards: 2 major transit POIs
# West Concourse: 7 major transit POIs
# West Farms/Bronx River: 1 major transit POIs
# West Village: 4 major transit POIs
# Westchester Village/Unionport: 2 major transit POIs
# Westerleigh failed: No matching features. Check query location, tags, and log.
# Whitestone failed: No matching features. Check query location, tags, and log.
# Willets Point failed: No matching features. Check query location, tags, and log.
# Williamsbridge/Olinville: 4 major transit POIs
# Williamsburg (North Side): 1 major transit POIs
# Williamsburg (South Side): 4 major transit POIs
# Windsor Terrace: 2 major transit POIs
# Woodhaven: 3 major transit POIs
# Woodlawn/Wakefield: 4 major transit POIs
# Woodside: 5 major transit POIs
# World Trade Center: 6 major transit POIs
# Yorkville East failed: No matching features. Check query location, tags, and log.
# Yorkville West: 1 major transit POIs

# %%
# Define hotel/lodging-related POI tags
tags = {
    "tourism": ["hotel", "motel", "hostel"],
    "building": ["hotel"]
}

# Loop through each zone and fetch transit POIs 
all_hotels = []

for idx, row in gdf.iterrows():
    zone_name = row["zone"]
    geom = row["geometry"]

    try:
        pois = ox.features_from_polygon(geom, tags)
        pois["zone"] = zone_name
        all_hotels.append(pois)
        print(f"{zone_name}: {len(pois)} hotel POIs")
    except Exception as e:
        print(f"{zone_name} failed: {e}")

# Combine all hotel/lodging POIs 
hotels_all = pd.concat(all_hotels, ignore_index=True)

# Convert to GeoDataFrame and reproject for area calc
hotels_gdf = gpd.GeoDataFrame(hotels_all, geometry="geometry", crs="EPSG:4326").to_crs("EPSG:2263")
# Out:
# Newark Airport: 2 hotel POIs
# Jamaica Bay failed: No matching features. Check query location, tags, and log.
# Allerton/Pelham Gardens: 1 hotel POIs
# Alphabet City failed: No matching features. Check query location, tags, and log.
# Arden Heights failed: No matching features. Check query location, tags, and log.
# Arrochar/Fort Wadsworth: 2 hotel POIs
# Astoria: 3 hotel POIs
# Astoria Park failed: No matching features. Check query location, tags, and log.
# Auburndale: 2 hotel POIs
# Baisley Park: 8 hotel POIs
# Bath Beach failed: No matching features. Check query location, tags, and log.
# Battery Park failed: No matching features. Check query location, tags, and log.
# Battery Park City: 1 hotel POIs
# Bay Ridge: 1 hotel POIs
# Bay Terrace/Fort Totten failed: No matching features. Check query location, tags, and log.
# Bayside: 3 hotel POIs
# Bedford: 1 hotel POIs
# Bedford Park failed: No matching features. Check query location, tags, and log.
# Bellerose: 1 hotel POIs
# Belmont: 1 hotel POIs
# Bensonhurst East: 1 hotel POIs
# Bensonhurst West failed: No matching features. Check query location, tags, and log.
# Bloomfield/Emerson Hill: 7 hotel POIs
# Bloomingdale: 1 hotel POIs
# Boerum Hill: 9 hotel POIs
# Borough Park: 1 hotel POIs
# Breezy Point/Fort Tilden/Riis Beach failed: No matching features. Check query location, tags, and log.
# Briarwood/Jamaica Hills: 5 hotel POIs
# Brighton Beach failed: No matching features. Check query location, tags, and log.
# Broad Channel failed: No matching features. Check query location, tags, and log.
# Bronx Park failed: No matching features. Check query location, tags, and log.
# Bronxdale failed: No matching features. Check query location, tags, and log.
# Brooklyn Heights: 2 hotel POIs
# Brooklyn Navy Yard failed: No matching features. Check query location, tags, and log.
# Brownsville: 2 hotel POIs
# Bushwick North: 1 hotel POIs
# Bushwick South: 6 hotel POIs
# Cambria Heights failed: No matching features. Check query location, tags, and log.
# Canarsie failed: No matching features. Check query location, tags, and log.
# Carroll Gardens failed: No matching features. Check query location, tags, and log.
# Central Harlem: 5 hotel POIs
# Central Harlem North failed: No matching features. Check query location, tags, and log.
# Central Park failed: No matching features. Check query location, tags, and log.
# Charleston/Tottenville: 2 hotel POIs
# Chinatown: 7 hotel POIs
# City Island failed: No matching features. Check query location, tags, and log.
# Claremont/Bathgate failed: No matching features. Check query location, tags, and log.
# Clinton East: 30 hotel POIs
# Clinton Hill failed: No matching features. Check query location, tags, and log.
# Clinton West: 5 hotel POIs
# Co-Op City: 1 hotel POIs
# Cobble Hill failed: No matching features. Check query location, tags, and log.
# College Point: 2 hotel POIs
# Columbia Street failed: No matching features. Check query location, tags, and log.
# Coney Island failed: No matching features. Check query location, tags, and log.
# Corona: 1 hotel POIs
# Corona: 3 hotel POIs
# Country Club failed: No matching features. Check query location, tags, and log.
# Crotona Park failed: No matching features. Check query location, tags, and log.
# Crotona Park East failed: No matching features. Check query location, tags, and log.
# Crown Heights North: 8 hotel POIs
# Crown Heights South failed: No matching features. Check query location, tags, and log.
# Cypress Hills failed: No matching features. Check query location, tags, and log.
# Douglaston failed: No matching features. Check query location, tags, and log.
# Downtown Brooklyn/MetroTech: 8 hotel POIs
# DUMBO/Vinegar Hill failed: No matching features. Check query location, tags, and log.
# Dyker Heights: 1 hotel POIs
# East Chelsea: 25 hotel POIs
# East Concourse/Concourse Village failed: No matching features. Check query location, tags, and log.
# East Elmhurst: 6 hotel POIs
# East Flatbush/Farragut failed: No matching features. Check query location, tags, and log.
# East Flatbush/Remsen Village failed: No matching features. Check query location, tags, and log.
# East Flushing failed: No matching features. Check query location, tags, and log.
# East Harlem North failed: No matching features. Check query location, tags, and log.
# East Harlem South failed: No matching features. Check query location, tags, and log.
# East New York: 5 hotel POIs
# East New York/Pennsylvania Avenue: 1 hotel POIs
# East Tremont failed: No matching features. Check query location, tags, and log.
# East Village: 5 hotel POIs
# East Williamsburg failed: No matching features. Check query location, tags, and log.
# Eastchester: 1 hotel POIs
# Elmhurst failed: No matching features. Check query location, tags, and log.
# Elmhurst/Maspeth: 5 hotel POIs
# Eltingville/Annadale/Prince's Bay failed: No matching features. Check query location, tags, and log.
# Erasmus failed: No matching features. Check query location, tags, and log.
# Far Rockaway failed: No matching features. Check query location, tags, and log.
# Financial District North: 19 hotel POIs
# Financial District South: 6 hotel POIs
# Flatbush/Ditmas Park: 3 hotel POIs
# Flatiron: 10 hotel POIs
# Flatlands failed: No matching features. Check query location, tags, and log.
# Flushing: 17 hotel POIs
# Flushing Meadows-Corona Park failed: No matching features. Check query location, tags, and log.
# Fordham South failed: No matching features. Check query location, tags, and log.
# Forest Hills failed: No matching features. Check query location, tags, and log.
# Forest Park/Highland Park failed: No matching features. Check query location, tags, and log.
# Fort Greene: 1 hotel POIs
# Fresh Meadows: 1 hotel POIs
# Freshkills Park failed: No matching features. Check query location, tags, and log.
# Garment District: 14 hotel POIs
# Glen Oaks: 1 hotel POIs
# Glendale failed: No matching features. Check query location, tags, and log.
# Governor's Island/Ellis Island/Liberty Island failed: No matching features. Check query location, tags, and log.
# Governor's Island/Ellis Island/Liberty Island failed: No matching features. Check query location, tags, and log.
# Governor's Island/Ellis Island/Liberty Island failed: No matching features. Check query location, tags, and log.
# Gowanus: 9 hotel POIs
# Gramercy: 12 hotel POIs
# Gravesend: 2 hotel POIs
# Great Kills failed: No matching features. Check query location, tags, and log.
# Great Kills Park failed: No matching features. Check query location, tags, and log.
# Green-Wood Cemetery failed: No matching features. Check query location, tags, and log.
# Greenpoint: 4 hotel POIs
# Greenwich Village North: 4 hotel POIs
# Greenwich Village South: 1 hotel POIs
# Grymes Hill/Clifton failed: No matching features. Check query location, tags, and log.
# Hamilton Heights: 2 hotel POIs
# Hammels/Arverne: 1 hotel POIs
# Heartland Village/Todt Hill failed: No matching features. Check query location, tags, and log.
# Highbridge: 1 hotel POIs
# Highbridge Park failed: No matching features. Check query location, tags, and log.
# Hillcrest/Pomonok: 1 hotel POIs
# Hollis failed: No matching features. Check query location, tags, and log.
# Homecrest failed: No matching features. Check query location, tags, and log.
# Howard Beach: 1 hotel POIs
# Hudson Sq: 6 hotel POIs
# Hunts Point failed: No matching features. Check query location, tags, and log.
# Inwood failed: No matching features. Check query location, tags, and log.
# Inwood Hill Park failed: No matching features. Check query location, tags, and log.
# Jackson Heights: 2 hotel POIs
# Jamaica: 12 hotel POIs
# Jamaica Estates failed: No matching features. Check query location, tags, and log.
# JFK Airport: 1 hotel POIs
# Kensington failed: No matching features. Check query location, tags, and log.
# Kew Gardens failed: No matching features. Check query location, tags, and log.
# Kew Gardens Hills: 1 hotel POIs
# Kingsbridge Heights failed: No matching features. Check query location, tags, and log.
# Kips Bay: 1 hotel POIs
# LaGuardia Airport failed: No matching features. Check query location, tags, and log.
# Laurelton failed: No matching features. Check query location, tags, and log.
# Lenox Hill East: 3 hotel POIs
# Lenox Hill West: 2 hotel POIs
# Lincoln Square East: 6 hotel POIs
# Lincoln Square West failed: No matching features. Check query location, tags, and log.
# Little Italy/NoLiTa: 12 hotel POIs
# Long Island City/Hunters Point: 11 hotel POIs
# Long Island City/Queens Plaza: 21 hotel POIs
# Longwood failed: No matching features. Check query location, tags, and log.
# Lower East Side: 25 hotel POIs
# Madison failed: No matching features. Check query location, tags, and log.
# Manhattan Beach: 3 hotel POIs
# Manhattan Valley: 4 hotel POIs
# Manhattanville failed: No matching features. Check query location, tags, and log.
# Marble Hill failed: No matching features. Check query location, tags, and log.
# Marine Park/Floyd Bennett Field failed: No matching features. Check query location, tags, and log.
# Marine Park/Mill Basin failed: No matching features. Check query location, tags, and log.
# Mariners Harbor failed: No matching features. Check query location, tags, and log.
# Maspeth: 3 hotel POIs
# Meatpacking/West Village West: 5 hotel POIs
# Melrose South: 1 hotel POIs
# Middle Village failed: No matching features. Check query location, tags, and log.
# Midtown Center: 21 hotel POIs
# Midtown East: 24 hotel POIs
# Midtown North: 26 hotel POIs
# Midtown South: 46 hotel POIs
# Midwood failed: No matching features. Check query location, tags, and log.
# Morningside Heights failed: No matching features. Check query location, tags, and log.
# Morrisania/Melrose: 1 hotel POIs
# Mott Haven/Port Morris: 2 hotel POIs
# Mount Hope failed: No matching features. Check query location, tags, and log.
# Murray Hill: 22 hotel POIs
# Murray Hill-Queens failed: No matching features. Check query location, tags, and log.
# New Dorp/Midland Beach failed: No matching features. Check query location, tags, and log.
# North Corona failed: No matching features. Check query location, tags, and log.
# Norwood: 2 hotel POIs
# Oakland Gardens failed: No matching features. Check query location, tags, and log.
# Oakwood failed: No matching features. Check query location, tags, and log.
# Ocean Hill: 4 hotel POIs
# Ocean Parkway South failed: No matching features. Check query location, tags, and log.
# Old Astoria failed: No matching features. Check query location, tags, and log.
# Ozone Park: 2 hotel POIs
# Park Slope failed: No matching features. Check query location, tags, and log.
# Parkchester failed: No matching features. Check query location, tags, and log.
# Pelham Bay: 1 hotel POIs
# Pelham Bay Park failed: No matching features. Check query location, tags, and log.
# Pelham Parkway failed: No matching features. Check query location, tags, and log.
# Penn Station/Madison Sq West: 15 hotel POIs
# Port Richmond failed: No matching features. Check query location, tags, and log.
# Prospect-Lefferts Gardens failed: No matching features. Check query location, tags, and log.
# Prospect Heights failed: No matching features. Check query location, tags, and log.
# Prospect Park failed: No matching features. Check query location, tags, and log.
# Queens Village: 1 hotel POIs
# Queensboro Hill failed: No matching features. Check query location, tags, and log.
# Queensbridge/Ravenswood: 11 hotel POIs
# Randalls Island failed: No matching features. Check query location, tags, and log.
# Red Hook: 2 hotel POIs
# Rego Park: 2 hotel POIs
# Richmond Hill failed: No matching features. Check query location, tags, and log.
# Ridgewood failed: No matching features. Check query location, tags, and log.
# Rikers Island failed: No matching features. Check query location, tags, and log.
# Riverdale/North Riverdale/Fieldston failed: No matching features. Check query location, tags, and log.
# Rockaway Park: 2 hotel POIs
# Roosevelt Island: 1 hotel POIs
# Rosedale: 1 hotel POIs
# Rossville/Woodrow: 2 hotel POIs
# Saint Albans failed: No matching features. Check query location, tags, and log.
# Saint George/New Brighton: 2 hotel POIs
# Saint Michaels Cemetery/Woodside failed: No matching features. Check query location, tags, and log.
# Schuylerville/Edgewater Park failed: No matching features. Check query location, tags, and log.
# Seaport: 4 hotel POIs
# Sheepshead Bay failed: No matching features. Check query location, tags, and log.
# SoHo: 5 hotel POIs
# Soundview/Bruckner failed: No matching features. Check query location, tags, and log.
# Soundview/Castle Hill failed: No matching features. Check query location, tags, and log.
# South Beach/Dongan Hills failed: No matching features. Check query location, tags, and log.
# South Jamaica: 1 hotel POIs
# South Ozone Park: 6 hotel POIs
# South Williamsburg failed: No matching features. Check query location, tags, and log.
# Springfield Gardens North: 5 hotel POIs
# Springfield Gardens South: 3 hotel POIs
# Spuyten Duyvil/Kingsbridge failed: No matching features. Check query location, tags, and log.
# Stapleton failed: No matching features. Check query location, tags, and log.
# Starrett City failed: No matching features. Check query location, tags, and log.
# Steinway: 1 hotel POIs
# Stuy Town/Peter Cooper Village failed: No matching features. Check query location, tags, and log.
# Stuyvesant Heights: 2 hotel POIs
# Sunnyside: 5 hotel POIs
# Sunset Park East: 7 hotel POIs
# Sunset Park West: 11 hotel POIs
# Sutton Place/Turtle Bay North: 4 hotel POIs
# Times Sq/Theatre District: 39 hotel POIs
# TriBeCa/Civic Center: 11 hotel POIs
# Two Bridges/Seward Park: 1 hotel POIs
# UN/Turtle Bay South: 7 hotel POIs
# Union Sq: 11 hotel POIs
# University Heights/Morris Heights failed: No matching features. Check query location, tags, and log.
# Upper East Side North: 4 hotel POIs
# Upper East Side South: 9 hotel POIs
# Upper West Side North: 5 hotel POIs
# Upper West Side South: 8 hotel POIs
# Van Cortlandt Park failed: No matching features. Check query location, tags, and log.
# Van Cortlandt Village failed: No matching features. Check query location, tags, and log.
# Van Nest/Morris Park: 1 hotel POIs
# Washington Heights North: 2 hotel POIs
# Washington Heights South failed: No matching features. Check query location, tags, and log.
# West Brighton failed: No matching features. Check query location, tags, and log.
# West Chelsea/Hudson Yards: 4 hotel POIs
# West Concourse: 1 hotel POIs
# West Farms/Bronx River failed: No matching features. Check query location, tags, and log.
# West Village failed: No matching features. Check query location, tags, and log.
# Westchester Village/Unionport failed: No matching features. Check query location, tags, and log.
# Westerleigh: 1 hotel POIs
# Whitestone: 1 hotel POIs
# Willets Point failed: No matching features. Check query location, tags, and log.
# Williamsbridge/Olinville: 2 hotel POIs
# Williamsburg (North Side): 10 hotel POIs
# Williamsburg (South Side): 4 hotel POIs
# Windsor Terrace failed: No matching features. Check query location, tags, and log.
# Woodhaven failed: No matching features. Check query location, tags, and log.
# Woodlawn/Wakefield: 1 hotel POIs
# Woodside: 4 hotel POIs
# World Trade Center: 10 hotel POIs
# Yorkville East: 1 hotel POIs
# Yorkville West: 1 hotel POIs

# %%
# Define event/venue-related POI tags
tags = {
    "leisure": ["stadium", "sports_centre", "amusement_park"],
    "amenity": ["theatre", "concert_hall", "arts_centre", "community_centre"]
}

# Loop through each zone and fetch event/venue POIs
all_venues = []

for idx, row in gdf.iterrows():
    zone_name = row["zone"]
    geom = row["geometry"]

    try:
        pois = ox.features_from_polygon(geom, tags)
        pois["zone"] = zone_name
        all_venues.append(pois)
        print(f"{zone_name}: {len(pois)} venues POIs")
    except Exception as e:
        print(f"{zone_name} failed: {e}")

# Combine all events/venue POIs
venues_all = pd.concat(all_venues, ignore_index=True)

# Convert to GeoDataFrame and reproject for area calc 
venues_gdf = gpd.GeoDataFrame(venues_all, geometry="geometry", crs="EPSG:4326").to_crs("EPSG:2263")
# Out:
# Newark Airport failed: No matching features. Check query location, tags, and log.
# Jamaica Bay failed: No matching features. Check query location, tags, and log.
# Allerton/Pelham Gardens failed: No matching features. Check query location, tags, and log.
# Alphabet City: 4 venues POIs
# Arden Heights: 2 venues POIs
# Arrochar/Fort Wadsworth failed: No matching features. Check query location, tags, and log.
# Astoria: 6 venues POIs
# Astoria Park failed: No matching features. Check query location, tags, and log.
# Auburndale failed: No matching features. Check query location, tags, and log.
# Baisley Park: 1 venues POIs
# Bath Beach failed: No matching features. Check query location, tags, and log.
# Battery Park: 1 venues POIs
# Battery Park City failed: No matching features. Check query location, tags, and log.
# Bay Ridge: 14 venues POIs
# Bay Terrace/Fort Totten: 2 venues POIs
# Bayside: 1 venues POIs
# Bedford: 6 venues POIs
# Bedford Park failed: No matching features. Check query location, tags, and log.
# Bellerose: 4 venues POIs
# Belmont failed: No matching features. Check query location, tags, and log.
# Bensonhurst East failed: No matching features. Check query location, tags, and log.
# Bensonhurst West: 2 venues POIs
# Bloomfield/Emerson Hill: 6 venues POIs
# Bloomingdale: 1 venues POIs
# Boerum Hill: 16 venues POIs
# Borough Park: 3 venues POIs
# Breezy Point/Fort Tilden/Riis Beach: 1 venues POIs
# Briarwood/Jamaica Hills failed: No matching features. Check query location, tags, and log.
# Brighton Beach: 4 venues POIs
# Broad Channel failed: No matching features. Check query location, tags, and log.
# Bronx Park: 1 venues POIs
# Bronxdale failed: No matching features. Check query location, tags, and log.
# Brooklyn Heights: 9 venues POIs
# Brooklyn Navy Yard failed: No matching features. Check query location, tags, and log.
# Brownsville: 3 venues POIs
# Bushwick North: 10 venues POIs
# Bushwick South: 11 venues POIs
# Cambria Heights failed: No matching features. Check query location, tags, and log.
# Canarsie: 1 venues POIs
# Carroll Gardens: 8 venues POIs
# Central Harlem: 5 venues POIs
# Central Harlem North: 8 venues POIs
# Central Park: 6 venues POIs
# Charleston/Tottenville: 8 venues POIs
# Chinatown: 5 venues POIs
# City Island failed: No matching features. Check query location, tags, and log.
# Claremont/Bathgate failed: No matching features. Check query location, tags, and log.
# Clinton East: 17 venues POIs
# Clinton Hill: 8 venues POIs
# Clinton West: 4 venues POIs
# Co-Op City failed: No matching features. Check query location, tags, and log.
# Cobble Hill: 1 venues POIs
# College Point failed: No matching features. Check query location, tags, and log.
# Columbia Street: 3 venues POIs
# Coney Island: 6 venues POIs
# Corona failed: No matching features. Check query location, tags, and log.
# Corona failed: No matching features. Check query location, tags, and log.
# Country Club failed: No matching features. Check query location, tags, and log.
# Crotona Park failed: No matching features. Check query location, tags, and log.
# Crotona Park East failed: No matching features. Check query location, tags, and log.
# Crown Heights North: 6 venues POIs
# Crown Heights South: 2 venues POIs
# Cypress Hills: 1 venues POIs
# Douglaston: 2 venues POIs
# Downtown Brooklyn/MetroTech: 1 venues POIs
# DUMBO/Vinegar Hill: 7 venues POIs
# Dyker Heights failed: No matching features. Check query location, tags, and log.
# East Chelsea: 16 venues POIs
# East Concourse/Concourse Village failed: No matching features. Check query location, tags, and log.
# East Elmhurst: 1 venues POIs
# East Flatbush/Farragut failed: No matching features. Check query location, tags, and log.
# East Flatbush/Remsen Village failed: No matching features. Check query location, tags, and log.
# East Flushing failed: No matching features. Check query location, tags, and log.
# East Harlem North: 9 venues POIs
# East Harlem South: 2 venues POIs
# East New York: 1 venues POIs
# East New York/Pennsylvania Avenue failed: No matching features. Check query location, tags, and log.
# East Tremont: 1 venues POIs
# East Village: 21 venues POIs
# East Williamsburg: 5 venues POIs
# Eastchester failed: No matching features. Check query location, tags, and log.
# Elmhurst failed: No matching features. Check query location, tags, and log.
# Elmhurst/Maspeth failed: No matching features. Check query location, tags, and log.
# Eltingville/Annadale/Prince's Bay: 3 venues POIs
# Erasmus: 2 venues POIs
# Far Rockaway failed: No matching features. Check query location, tags, and log.
# Financial District North: 1 venues POIs
# Financial District South failed: No matching features. Check query location, tags, and log.
# Flatbush/Ditmas Park: 2 venues POIs
# Flatiron: 4 venues POIs
# Flatlands failed: No matching features. Check query location, tags, and log.
# Flushing: 5 venues POIs
# Flushing Meadows-Corona Park: 12 venues POIs
# Fordham South: 2 venues POIs
# Forest Hills: 10 venues POIs
# Forest Park/Highland Park: 1 venues POIs
# Fort Greene: 16 venues POIs
# Fresh Meadows: 1 venues POIs
# Freshkills Park failed: No matching features. Check query location, tags, and log.
# Garment District: 4 venues POIs
# Glen Oaks: 1 venues POIs
# Glendale: 1 venues POIs
# Governor's Island/Ellis Island/Liberty Island: 1 venues POIs
# Governor's Island/Ellis Island/Liberty Island failed: No matching features. Check query location, tags, and log.
# Governor's Island/Ellis Island/Liberty Island: 2 venues POIs
# Gowanus: 20 venues POIs
# Gramercy: 11 venues POIs
# Gravesend: 2 venues POIs
# Great Kills: 4 venues POIs
# Great Kills Park failed: No matching features. Check query location, tags, and log.
# Green-Wood Cemetery failed: No matching features. Check query location, tags, and log.
# Greenpoint: 7 venues POIs
# Greenwich Village North: 6 venues POIs
# Greenwich Village South: 14 venues POIs
# Grymes Hill/Clifton: 2 venues POIs
# Hamilton Heights: 5 venues POIs
# Hammels/Arverne: 2 venues POIs
# Heartland Village/Todt Hill: 8 venues POIs
# Highbridge failed: No matching features. Check query location, tags, and log.
# Highbridge Park failed: No matching features. Check query location, tags, and log.
# Hillcrest/Pomonok: 2 venues POIs
# Hollis failed: No matching features. Check query location, tags, and log.
# Homecrest: 2 venues POIs
# Howard Beach failed: No matching features. Check query location, tags, and log.
# Hudson Sq: 3 venues POIs
# Hunts Point: 1 venues POIs
# Inwood failed: No matching features. Check query location, tags, and log.
# Inwood Hill Park: 1 venues POIs
# Jackson Heights: 5 venues POIs
# Jamaica: 5 venues POIs
# Jamaica Estates failed: No matching features. Check query location, tags, and log.
# JFK Airport failed: No matching features. Check query location, tags, and log.
# Kensington failed: No matching features. Check query location, tags, and log.
# Kew Gardens failed: No matching features. Check query location, tags, and log.
# Kew Gardens Hills: 4 venues POIs
# Kingsbridge Heights failed: No matching features. Check query location, tags, and log.
# Kips Bay: 3 venues POIs
# LaGuardia Airport failed: No matching features. Check query location, tags, and log.
# Laurelton failed: No matching features. Check query location, tags, and log.
# Lenox Hill East: 3 venues POIs
# Lenox Hill West failed: No matching features. Check query location, tags, and log.
# Lincoln Square East: 18 venues POIs
# Lincoln Square West: 6 venues POIs
# Little Italy/NoLiTa: 2 venues POIs
# Long Island City/Hunters Point: 9 venues POIs
# Long Island City/Queens Plaza: 2 venues POIs
# Longwood: 2 venues POIs
# Lower East Side: 13 venues POIs
# Madison: 3 venues POIs
# Manhattan Beach: 1 venues POIs
# Manhattan Valley: 1 venues POIs
# Manhattanville: 4 venues POIs
# Marble Hill failed: No matching features. Check query location, tags, and log.
# Marine Park/Floyd Bennett Field: 3 venues POIs
# Marine Park/Mill Basin failed: No matching features. Check query location, tags, and log.
# Mariners Harbor failed: No matching features. Check query location, tags, and log.
# Maspeth: 2 venues POIs
# Meatpacking/West Village West: 2 venues POIs
# Melrose South failed: No matching features. Check query location, tags, and log.
# Middle Village failed: No matching features. Check query location, tags, and log.
# Midtown Center: 3 venues POIs
# Midtown East failed: No matching features. Check query location, tags, and log.
# Midtown North: 6 venues POIs
# Midtown South: 3 venues POIs
# Midwood failed: No matching features. Check query location, tags, and log.
# Morningside Heights: 5 venues POIs
# Morrisania/Melrose failed: No matching features. Check query location, tags, and log.
# Mott Haven/Port Morris: 3 venues POIs
# Mount Hope failed: No matching features. Check query location, tags, and log.
# Murray Hill: 4 venues POIs
# Murray Hill-Queens: 1 venues POIs
# New Dorp/Midland Beach failed: No matching features. Check query location, tags, and log.
# North Corona failed: No matching features. Check query location, tags, and log.
# Norwood: 1 venues POIs
# Oakland Gardens: 4 venues POIs
# Oakwood failed: No matching features. Check query location, tags, and log.
# Ocean Hill: 1 venues POIs
# Ocean Parkway South failed: No matching features. Check query location, tags, and log.
# Old Astoria: 1 venues POIs
# Ozone Park failed: No matching features. Check query location, tags, and log.
# Park Slope: 21 venues POIs
# Parkchester failed: No matching features. Check query location, tags, and log.
# Pelham Bay failed: No matching features. Check query location, tags, and log.
# Pelham Bay Park failed: No matching features. Check query location, tags, and log.
# Pelham Parkway: 1 venues POIs
# Penn Station/Madison Sq West: 4 venues POIs
# Port Richmond failed: No matching features. Check query location, tags, and log.
# Prospect-Lefferts Gardens: 6 venues POIs
# Prospect Heights: 4 venues POIs
# Prospect Park: 5 venues POIs
# Queens Village: 2 venues POIs
# Queensboro Hill failed: No matching features. Check query location, tags, and log.
# Queensbridge/Ravenswood: 1 venues POIs
# Randalls Island: 2 venues POIs
# Red Hook: 8 venues POIs
# Rego Park: 2 venues POIs
# Richmond Hill: 1 venues POIs
# Ridgewood: 9 venues POIs
# Rikers Island failed: No matching features. Check query location, tags, and log.
# Riverdale/North Riverdale/Fieldston: 9 venues POIs
# Rockaway Park failed: No matching features. Check query location, tags, and log.
# Roosevelt Island: 2 venues POIs
# Rosedale: 1 venues POIs
# Rossville/Woodrow failed: No matching features. Check query location, tags, and log.
# Saint Albans: 2 venues POIs
# Saint George/New Brighton: 11 venues POIs
# Saint Michaels Cemetery/Woodside failed: No matching features. Check query location, tags, and log.
# Schuylerville/Edgewater Park: 1 venues POIs
# Seaport: 1 venues POIs
# Sheepshead Bay failed: No matching features. Check query location, tags, and log.
# SoHo: 2 venues POIs
# Soundview/Bruckner: 1 venues POIs
# Soundview/Castle Hill: 5 venues POIs
# South Beach/Dongan Hills: 3 venues POIs
# South Jamaica failed: No matching features. Check query location, tags, and log.
# South Ozone Park: 1 venues POIs
# South Williamsburg: 1 venues POIs
# Springfield Gardens North failed: No matching features. Check query location, tags, and log.
# Springfield Gardens South failed: No matching features. Check query location, tags, and log.
# Spuyten Duyvil/Kingsbridge failed: No matching features. Check query location, tags, and log.
# Stapleton: 4 venues POIs
# Starrett City failed: No matching features. Check query location, tags, and log.
# Steinway failed: No matching features. Check query location, tags, and log.
# Stuy Town/Peter Cooper Village failed: No matching features. Check query location, tags, and log.
# Stuyvesant Heights: 1 venues POIs
# Sunnyside: 7 venues POIs
# Sunset Park East: 5 venues POIs
# Sunset Park West: 7 venues POIs
# Sutton Place/Turtle Bay North: 1 venues POIs
# Times Sq/Theatre District: 50 venues POIs
# TriBeCa/Civic Center: 6 venues POIs
# Two Bridges/Seward Park: 7 venues POIs
# UN/Turtle Bay South: 2 venues POIs
# Union Sq: 5 venues POIs
# University Heights/Morris Heights: 3 venues POIs
# Upper East Side North: 5 venues POIs
# Upper East Side South: 2 venues POIs
# Upper West Side North: 8 venues POIs
# Upper West Side South: 3 venues POIs
# Van Cortlandt Park: 3 venues POIs
# Van Cortlandt Village failed: No matching features. Check query location, tags, and log.
# Van Nest/Morris Park: 2 venues POIs
# Washington Heights North: 4 venues POIs
# Washington Heights South: 7 venues POIs
# West Brighton: 1 venues POIs
# West Chelsea/Hudson Yards: 10 venues POIs
# West Concourse: 3 venues POIs
# West Farms/Bronx River failed: No matching features. Check query location, tags, and log.
# West Village: 5 venues POIs
# Westchester Village/Unionport: 2 venues POIs
# Westerleigh failed: No matching features. Check query location, tags, and log.
# Whitestone failed: No matching features. Check query location, tags, and log.
# Willets Point failed: No matching features. Check query location, tags, and log.
# Williamsbridge/Olinville failed: No matching features. Check query location, tags, and log.
# Williamsburg (North Side): 5 venues POIs
# Williamsburg (South Side): 5 venues POIs
# Windsor Terrace: 4 venues POIs
# Woodhaven failed: No matching features. Check query location, tags, and log.
# Woodlawn/Wakefield: 1 venues POIs
# Woodside: 1 venues POIs
# World Trade Center: 1 venues POIs
# Yorkville East: 3 venues POIs
# Yorkville West: 3 venues POIs

# %%
# Define restaurant-related POI tags
tags = {
    "amenity": ["restaurant", "cafe", "fast_food", "food_court"]
}

# Loop through each zone and fetch restaurant POIs
all_restaurants = []

for idx, row in gdf.iterrows():
    zone_name = row["zone"]
    geom = row["geometry"]

    try:
        pois = ox.features_from_polygon(geom, tags)
        pois["zone"] = zone_name
        all_restaurants.append(pois)
        print(f"{zone_name}: {len(pois)} restaurants POIs")
    except Exception as e:
        print(f"{zone_name} failed: {e}")

# Combine all events/venue POIs
restaurants_all = pd.concat(all_restaurants, ignore_index=True)

# Convert to GeoDataFrame and reproject for area calc
restaurants_gdf = gpd.GeoDataFrame(restaurants_all, geometry="geometry", crs="EPSG:4326").to_crs("EPSG:2263")
# Out:
# Newark Airport: 68 restaurants POIs
# Jamaica Bay failed: No matching features. Check query location, tags, and log.
# Allerton/Pelham Gardens: 6 restaurants POIs
# Alphabet City: 33 restaurants POIs
# Arden Heights: 5 restaurants POIs
# Arrochar/Fort Wadsworth: 15 restaurants POIs
# Astoria: 315 restaurants POIs
# Astoria Park failed: No matching features. Check query location, tags, and log.
# Auburndale: 11 restaurants POIs
# Baisley Park: 18 restaurants POIs
# Bath Beach: 21 restaurants POIs
# Battery Park: 3 restaurants POIs
# Battery Park City: 36 restaurants POIs
# Bay Ridge: 248 restaurants POIs
# Bay Terrace/Fort Totten: 21 restaurants POIs
# Bayside: 37 restaurants POIs
# Bedford: 123 restaurants POIs
# Bedford Park: 19 restaurants POIs
# Bellerose: 17 restaurants POIs
# Belmont: 31 restaurants POIs
# Bensonhurst East: 36 restaurants POIs
# Bensonhurst West: 117 restaurants POIs
# Bloomfield/Emerson Hill: 47 restaurants POIs
# Bloomingdale: 54 restaurants POIs
# Boerum Hill: 134 restaurants POIs
# Borough Park: 27 restaurants POIs
# Breezy Point/Fort Tilden/Riis Beach: 9 restaurants POIs
# Briarwood/Jamaica Hills: 33 restaurants POIs
# Brighton Beach: 42 restaurants POIs
# Broad Channel: 1 restaurants POIs
# Bronx Park: 6 restaurants POIs
# Bronxdale: 12 restaurants POIs
# Brooklyn Heights: 98 restaurants POIs
# Brooklyn Navy Yard: 9 restaurants POIs
# Brownsville: 11 restaurants POIs
# Bushwick North: 176 restaurants POIs
# Bushwick South: 100 restaurants POIs
# Cambria Heights: 19 restaurants POIs
# Canarsie: 14 restaurants POIs
# Carroll Gardens: 74 restaurants POIs
# Central Harlem: 87 restaurants POIs
# Central Harlem North: 55 restaurants POIs
# Central Park: 9 restaurants POIs
# Charleston/Tottenville: 62 restaurants POIs
# Chinatown: 137 restaurants POIs
# City Island: 16 restaurants POIs
# Claremont/Bathgate: 6 restaurants POIs
# Clinton East: 234 restaurants POIs
# Clinton Hill: 117 restaurants POIs
# Clinton West: 28 restaurants POIs
# Co-Op City: 16 restaurants POIs
# Cobble Hill: 39 restaurants POIs
# College Point: 7 restaurants POIs
# Columbia Street: 13 restaurants POIs
# Coney Island: 61 restaurants POIs
# Corona: 30 restaurants POIs
# Corona: 4 restaurants POIs
# Country Club: 1 restaurants POIs
# Crotona Park failed: No matching features. Check query location, tags, and log.
# Crotona Park East: 7 restaurants POIs
# Crown Heights North: 155 restaurants POIs
# Crown Heights South: 35 restaurants POIs
# Cypress Hills: 11 restaurants POIs
# Douglaston: 11 restaurants POIs
# Downtown Brooklyn/MetroTech: 68 restaurants POIs
# DUMBO/Vinegar Hill: 50 restaurants POIs
# Dyker Heights: 22 restaurants POIs
# East Chelsea: 159 restaurants POIs
# East Concourse/Concourse Village: 5 restaurants POIs
# East Elmhurst: 18 restaurants POIs
# East Flatbush/Farragut: 4 restaurants POIs
# East Flatbush/Remsen Village: 6 restaurants POIs
# East Flushing: 14 restaurants POIs
# East Harlem North: 80 restaurants POIs
# East Harlem South: 92 restaurants POIs
# East New York: 38 restaurants POIs
# East New York/Pennsylvania Avenue: 2 restaurants POIs
# East Tremont: 4 restaurants POIs
# East Village: 414 restaurants POIs
# East Williamsburg: 94 restaurants POIs
# Eastchester: 10 restaurants POIs
# Elmhurst: 93 restaurants POIs
# Elmhurst/Maspeth: 48 restaurants POIs
# Eltingville/Annadale/Prince's Bay: 27 restaurants POIs
# Erasmus: 5 restaurants POIs
# Far Rockaway: 15 restaurants POIs
# Financial District North: 143 restaurants POIs
# Financial District South: 77 restaurants POIs
# Flatbush/Ditmas Park: 94 restaurants POIs
# Flatiron: 88 restaurants POIs
# Flatlands: 11 restaurants POIs
# Flushing: 145 restaurants POIs
# Flushing Meadows-Corona Park: 15 restaurants POIs
# Fordham South: 20 restaurants POIs
# Forest Hills: 156 restaurants POIs
# Forest Park/Highland Park failed: No matching features. Check query location, tags, and log.
# Fort Greene: 97 restaurants POIs
# Fresh Meadows: 55 restaurants POIs
# Freshkills Park: 7 restaurants POIs
# Garment District: 123 restaurants POIs
# Glen Oaks: 42 restaurants POIs
# Glendale: 35 restaurants POIs
# Governor's Island/Ellis Island/Liberty Island: 3 restaurants POIs
# Governor's Island/Ellis Island/Liberty Island: 1 restaurants POIs
# Governor's Island/Ellis Island/Liberty Island: 7 restaurants POIs
# Gowanus: 51 restaurants POIs
# Gramercy: 163 restaurants POIs
# Gravesend: 10 restaurants POIs
# Great Kills: 68 restaurants POIs
# Great Kills Park failed: No matching features. Check query location, tags, and log.
# Green-Wood Cemetery failed: No matching features. Check query location, tags, and log.
# Greenpoint: 150 restaurants POIs
# Greenwich Village North: 109 restaurants POIs
# Greenwich Village South: 145 restaurants POIs
# Grymes Hill/Clifton: 3 restaurants POIs
# Hamilton Heights: 53 restaurants POIs
# Hammels/Arverne: 14 restaurants POIs
# Heartland Village/Todt Hill: 75 restaurants POIs
# Highbridge: 2 restaurants POIs
# Highbridge Park failed: No matching features. Check query location, tags, and log.
# Hillcrest/Pomonok: 34 restaurants POIs
# Hollis: 16 restaurants POIs
# Homecrest: 34 restaurants POIs
# Howard Beach: 15 restaurants POIs
# Hudson Sq: 26 restaurants POIs
# Hunts Point: 6 restaurants POIs
# Inwood: 26 restaurants POIs
# Inwood Hill Park failed: No matching features. Check query location, tags, and log.
# Jackson Heights: 137 restaurants POIs
# Jamaica: 135 restaurants POIs
# Jamaica Estates: 46 restaurants POIs
# JFK Airport: 60 restaurants POIs
# Kensington: 42 restaurants POIs
# Kew Gardens: 38 restaurants POIs
# Kew Gardens Hills: 41 restaurants POIs
# Kingsbridge Heights: 9 restaurants POIs
# Kips Bay: 65 restaurants POIs
# LaGuardia Airport: 37 restaurants POIs
# Laurelton: 27 restaurants POIs
# Lenox Hill East: 68 restaurants POIs
# Lenox Hill West: 115 restaurants POIs
# Lincoln Square East: 91 restaurants POIs
# Lincoln Square West: 26 restaurants POIs
# Little Italy/NoLiTa: 183 restaurants POIs
# Long Island City/Hunters Point: 131 restaurants POIs
# Long Island City/Queens Plaza: 42 restaurants POIs
# Longwood: 2 restaurants POIs
# Lower East Side: 223 restaurants POIs
# Madison: 35 restaurants POIs
# Manhattan Beach: 25 restaurants POIs
# Manhattan Valley: 63 restaurants POIs
# Manhattanville: 16 restaurants POIs
# Marble Hill: 4 restaurants POIs
# Marine Park/Floyd Bennett Field: 2 restaurants POIs
# Marine Park/Mill Basin: 13 restaurants POIs
# Mariners Harbor: 33 restaurants POIs
# Maspeth: 54 restaurants POIs
# Meatpacking/West Village West: 48 restaurants POIs
# Melrose South: 5 restaurants POIs
# Middle Village: 21 restaurants POIs
# Midtown Center: 162 restaurants POIs
# Midtown East: 144 restaurants POIs
# Midtown North: 100 restaurants POIs
# Midtown South: 188 restaurants POIs
# Midwood: 16 restaurants POIs
# Morningside Heights: 81 restaurants POIs
# Morrisania/Melrose: 5 restaurants POIs
# Mott Haven/Port Morris: 33 restaurants POIs
# Mount Hope: 7 restaurants POIs
# Murray Hill: 169 restaurants POIs
# Murray Hill-Queens: 30 restaurants POIs
# New Dorp/Midland Beach: 60 restaurants POIs
# North Corona: 37 restaurants POIs
# Norwood: 7 restaurants POIs
# Oakland Gardens: 44 restaurants POIs
# Oakwood: 10 restaurants POIs
# Ocean Hill: 17 restaurants POIs
# Ocean Parkway South: 1 restaurants POIs
# Old Astoria: 60 restaurants POIs
# Ozone Park: 15 restaurants POIs
# Park Slope: 330 restaurants POIs
# Parkchester: 26 restaurants POIs
# Pelham Bay: 12 restaurants POIs
# Pelham Bay Park failed: No matching features. Check query location, tags, and log.
# Pelham Parkway: 11 restaurants POIs
# Penn Station/Madison Sq West: 71 restaurants POIs
# Port Richmond: 21 restaurants POIs
# Prospect-Lefferts Gardens: 102 restaurants POIs
# Prospect Heights: 102 restaurants POIs
# Prospect Park: 11 restaurants POIs
# Queens Village: 41 restaurants POIs
# Queensboro Hill: 16 restaurants POIs
# Queensbridge/Ravenswood: 13 restaurants POIs
# Randalls Island failed: No matching features. Check query location, tags, and log.
# Red Hook: 35 restaurants POIs
# Rego Park: 43 restaurants POIs
# Richmond Hill: 54 restaurants POIs
# Ridgewood: 190 restaurants POIs
# Rikers Island failed: No matching features. Check query location, tags, and log.
# Riverdale/North Riverdale/Fieldston: 7 restaurants POIs
# Rockaway Park: 27 restaurants POIs
# Roosevelt Island: 5 restaurants POIs
# Rosedale: 22 restaurants POIs
# Rossville/Woodrow: 17 restaurants POIs
# Saint Albans: 41 restaurants POIs
# Saint George/New Brighton: 44 restaurants POIs
# Saint Michaels Cemetery/Woodside failed: No matching features. Check query location, tags, and log.
# Schuylerville/Edgewater Park: 13 restaurants POIs
# Seaport: 49 restaurants POIs
# Sheepshead Bay: 63 restaurants POIs
# SoHo: 76 restaurants POIs
# Soundview/Bruckner: 25 restaurants POIs
# Soundview/Castle Hill: 10 restaurants POIs
# South Beach/Dongan Hills: 44 restaurants POIs
# South Jamaica: 20 restaurants POIs
# South Ozone Park: 56 restaurants POIs
# South Williamsburg: 4 restaurants POIs
# Springfield Gardens North: 7 restaurants POIs
# Springfield Gardens South: 9 restaurants POIs
# Spuyten Duyvil/Kingsbridge: 29 restaurants POIs
# Stapleton: 49 restaurants POIs
# Starrett City: 3 restaurants POIs
# Steinway: 117 restaurants POIs
# Stuy Town/Peter Cooper Village: 10 restaurants POIs
# Stuyvesant Heights: 90 restaurants POIs
# Sunnyside: 165 restaurants POIs
# Sunset Park East: 131 restaurants POIs
# Sunset Park West: 160 restaurants POIs
# Sutton Place/Turtle Bay North: 77 restaurants POIs
# Times Sq/Theatre District: 148 restaurants POIs
# TriBeCa/Civic Center: 167 restaurants POIs
# Two Bridges/Seward Park: 83 restaurants POIs
# UN/Turtle Bay South: 58 restaurants POIs
# Union Sq: 169 restaurants POIs
# University Heights/Morris Heights: 7 restaurants POIs
# Upper East Side North: 119 restaurants POIs
# Upper East Side South: 76 restaurants POIs
# Upper West Side North: 93 restaurants POIs
# Upper West Side South: 144 restaurants POIs
# Van Cortlandt Park: 3 restaurants POIs
# Van Cortlandt Village failed: No matching features. Check query location, tags, and log.
# Van Nest/Morris Park: 26 restaurants POIs
# Washington Heights North: 47 restaurants POIs
# Washington Heights South: 57 restaurants POIs
# West Brighton: 30 restaurants POIs
# West Chelsea/Hudson Yards: 29 restaurants POIs
# West Concourse: 22 restaurants POIs
# West Farms/Bronx River: 8 restaurants POIs
# West Village: 180 restaurants POIs
# Westchester Village/Unionport: 16 restaurants POIs
# Westerleigh: 57 restaurants POIs
# Whitestone: 13 restaurants POIs
# Willets Point failed: No matching features. Check query location, tags, and log.
# Williamsbridge/Olinville: 5 restaurants POIs
# Williamsburg (North Side): 148 restaurants POIs
# Williamsburg (South Side): 116 restaurants POIs
# Windsor Terrace: 50 restaurants POIs
# Woodhaven: 51 restaurants POIs
# Woodlawn/Wakefield: 16 restaurants POIs
# Woodside: 103 restaurants POIs
# World Trade Center: 44 restaurants POIs
# Yorkville East: 28 restaurants POIs
# Yorkville West: 119 restaurants POIs

# %%
# Define tourism-related POI tags
tags = {
    "tourism": [
        "attraction", "museum", "gallery", "theme_park", "zoo", "aquarium"
    ],
    "historic": [
        "monument"
    ],
    "leisure": [
        "park"
    ]
}

# Loop through each zone and fetch tourism POIs
all_tourism = []

for idx, row in gdf.iterrows():
    zone_name = row["zone"]
    geom = row["geometry"]

    try:
        pois = ox.features_from_polygon(geom, tags)
        pois["zone"] = zone_name
        all_tourism.append(pois)
        print(f"{zone_name}: {len(pois)} tourism POIs")
    except Exception as e:
        print(f"{zone_name} failed: {e}")

# Combine all tourism POIs
tourism_all = pd.concat(all_tourism, ignore_index=True)

# Convert to GeoDataFrame and reproject for area calc 
tourism_gdf = gpd.GeoDataFrame(tourism_all, geometry="geometry", crs="EPSG:4326").to_crs("EPSG:2263")
# Out:
# Newark Airport failed: No matching features. Check query location, tags, and log.
# Jamaica Bay: 3 tourism POIs
# Allerton/Pelham Gardens: 5 tourism POIs
# Alphabet City: 6 tourism POIs
# Arden Heights: 2 tourism POIs
# Arrochar/Fort Wadsworth: 15 tourism POIs
# Astoria: 10 tourism POIs
# Astoria Park: 2 tourism POIs
# Auburndale: 2 tourism POIs
# Baisley Park: 5 tourism POIs
# Bath Beach: 3 tourism POIs
# Battery Park: 3 tourism POIs
# Battery Park City: 21 tourism POIs
# Bay Ridge: 22 tourism POIs
# Bay Terrace/Fort Totten: 8 tourism POIs
# Bayside: 11 tourism POIs
# Bedford: 15 tourism POIs
# Bedford Park: 10 tourism POIs
# Bellerose: 19 tourism POIs
# Belmont: 14 tourism POIs
# Bensonhurst East: 11 tourism POIs
# Bensonhurst West: 4 tourism POIs
# Bloomfield/Emerson Hill: 12 tourism POIs
# Bloomingdale: 10 tourism POIs
# Boerum Hill: 12 tourism POIs
# Borough Park: 9 tourism POIs
# Breezy Point/Fort Tilden/Riis Beach: 3 tourism POIs
# Briarwood/Jamaica Hills: 6 tourism POIs
# Brighton Beach: 8 tourism POIs
# Broad Channel: 4 tourism POIs
# Bronx Park: 29 tourism POIs
# Bronxdale: 4 tourism POIs
# Brooklyn Heights: 15 tourism POIs
# Brooklyn Navy Yard: 3 tourism POIs
# Brownsville: 19 tourism POIs
# Bushwick North: 12 tourism POIs
# Bushwick South: 17 tourism POIs
# Cambria Heights: 6 tourism POIs
# Canarsie: 12 tourism POIs
# Carroll Gardens: 8 tourism POIs
# Central Harlem: 9 tourism POIs
# Central Harlem North: 23 tourism POIs
# Central Park: 32 tourism POIs
# Charleston/Tottenville: 12 tourism POIs
# Chinatown: 23 tourism POIs
# City Island: 7 tourism POIs
# Claremont/Bathgate: 11 tourism POIs
# Clinton East: 6 tourism POIs
# Clinton Hill: 10 tourism POIs
# Clinton West: 10 tourism POIs
# Co-Op City: 1 tourism POIs
# Cobble Hill: 3 tourism POIs
# College Point: 8 tourism POIs
# Columbia Street: 3 tourism POIs
# Coney Island: 50 tourism POIs
# Corona: 8 tourism POIs
# Corona: 1 tourism POIs
# Country Club: 1 tourism POIs
# Crotona Park: 1 tourism POIs
# Crotona Park East: 9 tourism POIs
# Crown Heights North: 19 tourism POIs
# Crown Heights South: 4 tourism POIs
# Cypress Hills: 8 tourism POIs
# Douglaston: 21 tourism POIs
# Downtown Brooklyn/MetroTech: 15 tourism POIs
# DUMBO/Vinegar Hill: 21 tourism POIs
# Dyker Heights: 7 tourism POIs
# East Chelsea: 11 tourism POIs
# East Concourse/Concourse Village: 9 tourism POIs
# East Elmhurst: 12 tourism POIs
# East Flatbush/Farragut: 3 tourism POIs
# East Flatbush/Remsen Village: 6 tourism POIs
# East Flushing: 3 tourism POIs
# East Harlem North: 18 tourism POIs
# East Harlem South: 23 tourism POIs
# East New York: 19 tourism POIs
# East New York/Pennsylvania Avenue: 9 tourism POIs
# East Tremont: 22 tourism POIs
# East Village: 27 tourism POIs
# East Williamsburg: 17 tourism POIs
# Eastchester: 9 tourism POIs
# Elmhurst: 16 tourism POIs
# Elmhurst/Maspeth: 8 tourism POIs
# Eltingville/Annadale/Prince's Bay: 17 tourism POIs
# Erasmus: 2 tourism POIs
# Far Rockaway: 17 tourism POIs
# Financial District North: 15 tourism POIs
# Financial District South: 8 tourism POIs
# Flatbush/Ditmas Park: 5 tourism POIs
# Flatiron: 4 tourism POIs
# Flatlands: 10 tourism POIs
# Flushing: 37 tourism POIs
# Flushing Meadows-Corona Park: 31 tourism POIs
# Fordham South: 3 tourism POIs
# Forest Hills: 23 tourism POIs
# Forest Park/Highland Park: 3 tourism POIs
# Fort Greene: 17 tourism POIs
# Fresh Meadows: 17 tourism POIs
# Freshkills Park: 4 tourism POIs
# Garment District: 6 tourism POIs
# Glen Oaks: 12 tourism POIs
# Glendale: 5 tourism POIs
# Governor's Island/Ellis Island/Liberty Island: 3 tourism POIs
# Governor's Island/Ellis Island/Liberty Island: 2 tourism POIs
# Governor's Island/Ellis Island/Liberty Island: 7 tourism POIs
# Gowanus: 7 tourism POIs
# Gramercy: 5 tourism POIs
# Gravesend: 9 tourism POIs
# Great Kills: 12 tourism POIs
# Great Kills Park: 3 tourism POIs
# Green-Wood Cemetery: 6 tourism POIs
# Greenpoint: 22 tourism POIs
# Greenwich Village North: 10 tourism POIs
# Greenwich Village South: 16 tourism POIs
# Grymes Hill/Clifton: 8 tourism POIs
# Hamilton Heights: 11 tourism POIs
# Hammels/Arverne: 14 tourism POIs
# Heartland Village/Todt Hill: 18 tourism POIs
# Highbridge: 13 tourism POIs
# Highbridge Park: 3 tourism POIs
# Hillcrest/Pomonok: 7 tourism POIs
# Hollis: 5 tourism POIs
# Homecrest: 7 tourism POIs
# Howard Beach: 7 tourism POIs
# Hudson Sq: 13 tourism POIs
# Hunts Point: 22 tourism POIs
# Inwood: 7 tourism POIs
# Inwood Hill Park: 4 tourism POIs
# Jackson Heights: 34 tourism POIs
# Jamaica: 13 tourism POIs
# Jamaica Estates: 9 tourism POIs
# JFK Airport: 3 tourism POIs
# Kensington: 2 tourism POIs
# Kew Gardens: 5 tourism POIs
# Kew Gardens Hills: 39 tourism POIs
# Kingsbridge Heights: 5 tourism POIs
# Kips Bay: 8 tourism POIs
# LaGuardia Airport: 4 tourism POIs
# Laurelton: 1 tourism POIs
# Lenox Hill East: 7 tourism POIs
# Lenox Hill West: 4 tourism POIs
# Lincoln Square East: 17 tourism POIs
# Lincoln Square West: 11 tourism POIs
# Little Italy/NoLiTa: 19 tourism POIs
# Long Island City/Hunters Point: 28 tourism POIs
# Long Island City/Queens Plaza: 6 tourism POIs
# Longwood: 11 tourism POIs
# Lower East Side: 44 tourism POIs
# Madison: 6 tourism POIs
# Manhattan Beach: 6 tourism POIs
# Manhattan Valley: 7 tourism POIs
# Manhattanville: 13 tourism POIs
# Marble Hill: 1 tourism POIs
# Marine Park/Floyd Bennett Field: 11 tourism POIs
# Marine Park/Mill Basin: 12 tourism POIs
# Mariners Harbor: 5 tourism POIs
# Maspeth: 16 tourism POIs
# Meatpacking/West Village West: 11 tourism POIs
# Melrose South: 14 tourism POIs
# Middle Village: 4 tourism POIs
# Midtown Center: 16 tourism POIs
# Midtown East: 2 tourism POIs
# Midtown North: 7 tourism POIs
# Midtown South: 18 tourism POIs
# Midwood: 4 tourism POIs
# Morningside Heights: 22 tourism POIs
# Morrisania/Melrose: 18 tourism POIs
# Mott Haven/Port Morris: 25 tourism POIs
# Mount Hope: 18 tourism POIs
# Murray Hill: 7 tourism POIs
# Murray Hill-Queens: 18 tourism POIs
# New Dorp/Midland Beach: 6 tourism POIs
# North Corona: 9 tourism POIs
# Norwood: 5 tourism POIs
# Oakland Gardens: 19 tourism POIs
# Oakwood: 6 tourism POIs
# Ocean Hill: 10 tourism POIs
# Ocean Parkway South: 2 tourism POIs
# Old Astoria: 4 tourism POIs
# Ozone Park: 8 tourism POIs
# Park Slope: 13 tourism POIs
# Parkchester: 10 tourism POIs
# Pelham Bay: 2 tourism POIs
# Pelham Bay Park: 3 tourism POIs
# Pelham Parkway: 2 tourism POIs
# Penn Station/Madison Sq West: 3 tourism POIs
# Port Richmond: 7 tourism POIs
# Prospect-Lefferts Gardens: 6 tourism POIs
# Prospect Heights: 8 tourism POIs
# Prospect Park: 28 tourism POIs
# Queens Village: 12 tourism POIs
# Queensboro Hill: 8 tourism POIs
# Queensbridge/Ravenswood: 6 tourism POIs
# Randalls Island: 2 tourism POIs
# Red Hook: 15 tourism POIs
# Rego Park: 7 tourism POIs
# Richmond Hill: 6 tourism POIs
# Ridgewood: 18 tourism POIs
# Rikers Island failed: No matching features. Check query location, tags, and log.
# Riverdale/North Riverdale/Fieldston: 26 tourism POIs
# Rockaway Park: 15 tourism POIs
# Roosevelt Island: 14 tourism POIs
# Rosedale: 7 tourism POIs
# Rossville/Woodrow: 5 tourism POIs
# Saint Albans: 9 tourism POIs
# Saint George/New Brighton: 29 tourism POIs
# Saint Michaels Cemetery/Woodside: 1 tourism POIs
# Schuylerville/Edgewater Park: 15 tourism POIs
# Seaport: 11 tourism POIs
# Sheepshead Bay: 10 tourism POIs
# SoHo: 23 tourism POIs
# Soundview/Bruckner: 6 tourism POIs
# Soundview/Castle Hill: 13 tourism POIs
# South Beach/Dongan Hills: 5 tourism POIs
# South Jamaica: 10 tourism POIs
# South Ozone Park: 10 tourism POIs
# South Williamsburg: 17 tourism POIs
# Springfield Gardens North: 7 tourism POIs
# Springfield Gardens South: 5 tourism POIs
# Spuyten Duyvil/Kingsbridge: 10 tourism POIs
# Stapleton: 15 tourism POIs
# Starrett City: 2 tourism POIs
# Steinway: 21 tourism POIs
# Stuy Town/Peter Cooper Village: 6 tourism POIs
# Stuyvesant Heights: 16 tourism POIs
# Sunnyside: 30 tourism POIs
# Sunset Park East: 7 tourism POIs
# Sunset Park West: 9 tourism POIs
# Sutton Place/Turtle Bay North: 7 tourism POIs
# Times Sq/Theatre District: 12 tourism POIs
# TriBeCa/Civic Center: 43 tourism POIs
# Two Bridges/Seward Park: 28 tourism POIs
# UN/Turtle Bay South: 17 tourism POIs
# Union Sq: 13 tourism POIs
# University Heights/Morris Heights: 17 tourism POIs
# Upper East Side North: 8 tourism POIs
# Upper East Side South: 10 tourism POIs
# Upper West Side North: 12 tourism POIs
# Upper West Side South: 13 tourism POIs
# Van Cortlandt Park: 4 tourism POIs
# Van Cortlandt Village: 13 tourism POIs
# Van Nest/Morris Park: 10 tourism POIs
# Washington Heights North: 12 tourism POIs
# Washington Heights South: 14 tourism POIs
# West Brighton: 7 tourism POIs
# West Chelsea/Hudson Yards: 127 tourism POIs
# West Concourse: 13 tourism POIs
# West Farms/Bronx River: 5 tourism POIs
# West Village: 26 tourism POIs
# Westchester Village/Unionport: 5 tourism POIs
# Westerleigh: 7 tourism POIs
# Whitestone: 19 tourism POIs
# Willets Point: 1 tourism POIs
# Williamsbridge/Olinville: 5 tourism POIs
# Williamsburg (North Side): 18 tourism POIs
# Williamsburg (South Side): 20 tourism POIs
# Windsor Terrace: 8 tourism POIs
# Woodhaven: 9 tourism POIs
# Woodlawn/Wakefield: 5 tourism POIs
# Woodside: 18 tourism POIs
# World Trade Center: 12 tourism POIs
# Yorkville East: 3 tourism POIs
# Yorkville West: 4 tourism POIs

# %%
# Define education-related POI tags
tags = {
    "amenity": [
        "school", "college", "university", "kindergarten", "library"
    ]
}

# Loop through each zone and fetch education POIs
all_education = []

for idx, row in gdf.iterrows():
    zone_name = row["zone"]
    geom = row["geometry"]

    try:
        pois = ox.features_from_polygon(geom, tags)
        pois["zone"] = zone_name
        all_education.append(pois)
        print(f"{zone_name}: {len(pois)} education POIs")
    except Exception as e:
        print(f"{zone_name} failed: {e}")

# Combine all education POIs
education_all = pd.concat(all_education, ignore_index=True)

# Convert to GeoDataFrame and reproject for area calc 
education_gdf = gpd.GeoDataFrame(education_all, geometry="geometry", crs="EPSG:4326").to_crs("EPSG:2263")
# Out:
# Newark Airport failed: No matching features. Check query location, tags, and log.
# Jamaica Bay failed: No matching features. Check query location, tags, and log.
# Allerton/Pelham Gardens: 6 education POIs
# Alphabet City: 7 education POIs
# Arden Heights: 2 education POIs
# Arrochar/Fort Wadsworth: 10 education POIs
# Astoria: 11 education POIs
# Astoria Park failed: No matching features. Check query location, tags, and log.
# Auburndale: 4 education POIs
# Baisley Park: 6 education POIs
# Bath Beach: 6 education POIs
# Battery Park failed: No matching features. Check query location, tags, and log.
# Battery Park City: 2 education POIs
# Bay Ridge: 24 education POIs
# Bay Terrace/Fort Totten: 6 education POIs
# Bayside: 10 education POIs
# Bedford: 20 education POIs
# Bedford Park: 7 education POIs
# Bellerose: 7 education POIs
# Belmont: 15 education POIs
# Bensonhurst East: 11 education POIs
# Bensonhurst West: 17 education POIs
# Bloomfield/Emerson Hill: 15 education POIs
# Bloomingdale: 6 education POIs
# Boerum Hill: 29 education POIs
# Borough Park: 30 education POIs
# Breezy Point/Fort Tilden/Riis Beach failed: No matching features. Check query location, tags, and log.
# Briarwood/Jamaica Hills: 14 education POIs
# Brighton Beach: 8 education POIs
# Broad Channel: 1 education POIs
# Bronx Park: 1 education POIs
# Bronxdale: 9 education POIs
# Brooklyn Heights: 23 education POIs
# Brooklyn Navy Yard failed: No matching features. Check query location, tags, and log.
# Brownsville: 15 education POIs
# Bushwick North: 17 education POIs
# Bushwick South: 11 education POIs
# Cambria Heights: 10 education POIs
# Canarsie: 15 education POIs
# Carroll Gardens: 17 education POIs
# Central Harlem: 16 education POIs
# Central Harlem North: 27 education POIs
# Central Park: 1 education POIs
# Charleston/Tottenville: 10 education POIs
# Chinatown: 9 education POIs
# City Island: 2 education POIs
# Claremont/Bathgate: 12 education POIs
# Clinton East: 12 education POIs
# Clinton Hill: 19 education POIs
# Clinton West: 3 education POIs
# Co-Op City: 4 education POIs
# Cobble Hill: 6 education POIs
# College Point: 6 education POIs
# Columbia Street: 1 education POIs
# Coney Island: 11 education POIs
# Corona: 8 education POIs
# Corona failed: No matching features. Check query location, tags, and log.
# Country Club failed: No matching features. Check query location, tags, and log.
# Crotona Park: 1 education POIs
# Crotona Park East: 6 education POIs
# Crown Heights North: 31 education POIs
# Crown Heights South: 10 education POIs
# Cypress Hills: 9 education POIs
# Douglaston: 10 education POIs
# Downtown Brooklyn/MetroTech: 17 education POIs
# DUMBO/Vinegar Hill: 9 education POIs
# Dyker Heights: 9 education POIs
# East Chelsea: 14 education POIs
# East Concourse/Concourse Village: 20 education POIs
# East Elmhurst: 5 education POIs
# East Flatbush/Farragut: 9 education POIs
# East Flatbush/Remsen Village: 14 education POIs
# East Flushing: 4 education POIs
# East Harlem North: 18 education POIs
# East Harlem South: 19 education POIs
# East New York: 24 education POIs
# East New York/Pennsylvania Avenue: 8 education POIs
# East Tremont: 7 education POIs
# East Village: 16 education POIs
# East Williamsburg: 15 education POIs
# Eastchester: 3 education POIs
# Elmhurst: 10 education POIs
# Elmhurst/Maspeth: 5 education POIs
# Eltingville/Annadale/Prince's Bay: 12 education POIs
# Erasmus: 9 education POIs
# Far Rockaway: 15 education POIs
# Financial District North: 3 education POIs
# Financial District South: 6 education POIs
# Flatbush/Ditmas Park: 23 education POIs
# Flatiron: 5 education POIs
# Flatlands: 8 education POIs
# Flushing: 14 education POIs
# Flushing Meadows-Corona Park: 1 education POIs
# Fordham South: 4 education POIs
# Forest Hills: 20 education POIs
# Forest Park/Highland Park failed: No matching features. Check query location, tags, and log.
# Fort Greene: 13 education POIs
# Fresh Meadows: 6 education POIs
# Freshkills Park: 1 education POIs
# Garment District: 1 education POIs
# Glen Oaks: 5 education POIs
# Glendale: 6 education POIs
# Governor's Island/Ellis Island/Liberty Island failed: No matching features. Check query location, tags, and log.
# Governor's Island/Ellis Island/Liberty Island: 1 education POIs
# Governor's Island/Ellis Island/Liberty Island: 2 education POIs
# Gowanus: 6 education POIs
# Gramercy: 16 education POIs
# Gravesend: 9 education POIs
# Great Kills: 12 education POIs
# Great Kills Park failed: No matching features. Check query location, tags, and log.
# Green-Wood Cemetery failed: No matching features. Check query location, tags, and log.
# Greenpoint: 9 education POIs
# Greenwich Village North: 23 education POIs
# Greenwich Village South: 11 education POIs
# Grymes Hill/Clifton: 11 education POIs
# Hamilton Heights: 7 education POIs
# Hammels/Arverne: 7 education POIs
# Heartland Village/Todt Hill: 15 education POIs
# Highbridge: 1 education POIs
# Highbridge Park: 1 education POIs
# Hillcrest/Pomonok: 9 education POIs
# Hollis: 8 education POIs
# Homecrest: 12 education POIs
# Howard Beach: 6 education POIs
# Hudson Sq: 3 education POIs
# Hunts Point: 5 education POIs
# Inwood: 8 education POIs
# Inwood Hill Park failed: No matching features. Check query location, tags, and log.
# Jackson Heights: 17 education POIs
# Jamaica: 15 education POIs
# Jamaica Estates: 7 education POIs
# JFK Airport: 1 education POIs
# Kensington: 9 education POIs
# Kew Gardens: 5 education POIs
# Kew Gardens Hills: 14 education POIs
# Kingsbridge Heights: 4 education POIs
# Kips Bay: 9 education POIs
# LaGuardia Airport failed: No matching features. Check query location, tags, and log.
# Laurelton: 8 education POIs
# Lenox Hill East: 7 education POIs
# Lenox Hill West: 11 education POIs
# Lincoln Square East: 15 education POIs
# Lincoln Square West: 19 education POIs
# Little Italy/NoLiTa: 3 education POIs
# Long Island City/Hunters Point: 13 education POIs
# Long Island City/Queens Plaza: 6 education POIs
# Longwood: 7 education POIs
# Lower East Side: 12 education POIs
# Madison: 17 education POIs
# Manhattan Beach: 4 education POIs
# Manhattan Valley: 8 education POIs
# Manhattanville: 15 education POIs
# Marble Hill: 2 education POIs
# Marine Park/Floyd Bennett Field: 2 education POIs
# Marine Park/Mill Basin: 8 education POIs
# Mariners Harbor: 7 education POIs
# Maspeth: 7 education POIs
# Meatpacking/West Village West: 1 education POIs
# Melrose South: 21 education POIs
# Middle Village: 4 education POIs
# Midtown Center: 3 education POIs
# Midtown East: 5 education POIs
# Midtown North: 1 education POIs
# Midtown South: 9 education POIs
# Midwood: 17 education POIs
# Morningside Heights: 25 education POIs
# Morrisania/Melrose: 13 education POIs
# Mott Haven/Port Morris: 25 education POIs
# Mount Hope: 3 education POIs
# Murray Hill: 10 education POIs
# Murray Hill-Queens: 7 education POIs
# New Dorp/Midland Beach: 13 education POIs
# North Corona: 7 education POIs
# Norwood: 6 education POIs
# Oakland Gardens: 12 education POIs
# Oakwood: 6 education POIs
# Ocean Hill: 5 education POIs
# Ocean Parkway South: 4 education POIs
# Old Astoria: 7 education POIs
# Ozone Park: 4 education POIs
# Park Slope: 66 education POIs
# Parkchester: 3 education POIs
# Pelham Bay: 2 education POIs
# Pelham Bay Park failed: No matching features. Check query location, tags, and log.
# Pelham Parkway: 6 education POIs
# Penn Station/Madison Sq West: 4 education POIs
# Port Richmond: 9 education POIs
# Prospect-Lefferts Gardens: 28 education POIs
# Prospect Heights: 12 education POIs
# Prospect Park: 1 education POIs
# Queens Village: 10 education POIs
# Queensboro Hill: 5 education POIs
# Queensbridge/Ravenswood: 6 education POIs
# Randalls Island: 1 education POIs
# Red Hook: 8 education POIs
# Rego Park: 6 education POIs
# Richmond Hill: 13 education POIs
# Ridgewood: 21 education POIs
# Rikers Island failed: No matching features. Check query location, tags, and log.
# Riverdale/North Riverdale/Fieldston: 23 education POIs
# Rockaway Park: 8 education POIs
# Roosevelt Island: 4 education POIs
# Rosedale: 6 education POIs
# Rossville/Woodrow: 5 education POIs
# Saint Albans: 10 education POIs
# Saint George/New Brighton: 17 education POIs
# Saint Michaels Cemetery/Woodside failed: No matching features. Check query location, tags, and log.
# Schuylerville/Edgewater Park: 17 education POIs
# Seaport: 5 education POIs
# Sheepshead Bay: 16 education POIs
# SoHo: 1 education POIs
# Soundview/Bruckner: 5 education POIs
# Soundview/Castle Hill: 21 education POIs
# South Beach/Dongan Hills: 6 education POIs
# South Jamaica: 5 education POIs
# South Ozone Park: 14 education POIs
# South Williamsburg: 23 education POIs
# Springfield Gardens North: 6 education POIs
# Springfield Gardens South: 4 education POIs
# Spuyten Duyvil/Kingsbridge: 7 education POIs
# Stapleton: 7 education POIs
# Starrett City: 1 education POIs
# Steinway: 11 education POIs
# Stuy Town/Peter Cooper Village failed: No matching features. Check query location, tags, and log.
# Stuyvesant Heights: 13 education POIs
# Sunnyside: 11 education POIs
# Sunset Park East: 7 education POIs
# Sunset Park West: 25 education POIs
# Sutton Place/Turtle Bay North: 4 education POIs
# Times Sq/Theatre District: 1 education POIs
# TriBeCa/Civic Center: 5 education POIs
# Two Bridges/Seward Park: 16 education POIs
# UN/Turtle Bay South: 4 education POIs
# Union Sq: 14 education POIs
# University Heights/Morris Heights: 14 education POIs
# Upper East Side North: 25 education POIs
# Upper East Side South: 11 education POIs
# Upper West Side North: 26 education POIs
# Upper West Side South: 11 education POIs
# Van Cortlandt Park failed: No matching features. Check query location, tags, and log.
# Van Cortlandt Village: 13 education POIs
# Van Nest/Morris Park: 9 education POIs
# Washington Heights North: 20 education POIs
# Washington Heights South: 10 education POIs
# West Brighton: 9 education POIs
# West Chelsea/Hudson Yards: 2 education POIs
# West Concourse: 5 education POIs
# West Farms/Bronx River: 8 education POIs
# West Village: 11 education POIs
# Westchester Village/Unionport: 7 education POIs
# Westerleigh: 8 education POIs
# Whitestone: 10 education POIs
# Willets Point failed: No matching features. Check query location, tags, and log.
# Williamsbridge/Olinville: 18 education POIs
# Williamsburg (North Side): 10 education POIs
# Williamsburg (South Side): 11 education POIs
# Windsor Terrace: 20 education POIs
# Woodhaven: 13 education POIs
# Woodlawn/Wakefield: 9 education POIs
# Woodside: 5 education POIs
# World Trade Center: 3 education POIs
# Yorkville East: 5 education POIs
# Yorkville West: 9 education POIs

# %%
# Define healthcare-related POI tags
tags = {
    "healthcare": [
        "hospital", "clinic", "doctor", "pharmacy", "dentist"]
}

# Loop through each zone and fetch education POIs
all_healthcare = []

for idx, row in gdf.iterrows():
    zone_name = row["zone"]
    geom = row["geometry"]

    try:
        pois = ox.features_from_polygon(geom, tags)
        pois["zone"] = zone_name
        all_healthcare.append(pois)
        print(f"{zone_name}: {len(pois)} healthcare POIs")
    except Exception as e:
        print(f"{zone_name} failed: {e}")

# Combine all healthcare POIs
healthcare_all = pd.concat(all_healthcare, ignore_index=True)

# Convert to GeoDataFrame and reproject for area calc 
healthcare_gdf = gpd.GeoDataFrame(healthcare_all, geometry="geometry", crs="EPSG:4326").to_crs("EPSG:2263")
# Out:
# Newark Airport failed: No matching features. Check query location, tags, and log.
# Jamaica Bay failed: No matching features. Check query location, tags, and log.
# Allerton/Pelham Gardens: 3 healthcare POIs
# Alphabet City: 9 healthcare POIs
# Arden Heights: 1 healthcare POIs
# Arrochar/Fort Wadsworth: 8 healthcare POIs
# Astoria: 52 healthcare POIs
# Astoria Park failed: No matching features. Check query location, tags, and log.
# Auburndale: 5 healthcare POIs
# Baisley Park: 2 healthcare POIs
# Bath Beach: 7 healthcare POIs
# Battery Park failed: No matching features. Check query location, tags, and log.
# Battery Park City: 2 healthcare POIs
# Bay Ridge: 104 healthcare POIs
# Bay Terrace/Fort Totten: 3 healthcare POIs
# Bayside: 6 healthcare POIs
# Bedford: 16 healthcare POIs
# Bedford Park: 11 healthcare POIs
# Bellerose: 14 healthcare POIs
# Belmont: 4 healthcare POIs
# Bensonhurst East: 9 healthcare POIs
# Bensonhurst West: 29 healthcare POIs
# Bloomfield/Emerson Hill: 58 healthcare POIs
# Bloomingdale: 7 healthcare POIs
# Boerum Hill: 38 healthcare POIs
# Borough Park: 13 healthcare POIs
# Breezy Point/Fort Tilden/Riis Beach: 1 healthcare POIs
# Briarwood/Jamaica Hills: 12 healthcare POIs
# Brighton Beach: 46 healthcare POIs
# Broad Channel failed: No matching features. Check query location, tags, and log.
# Bronx Park failed: No matching features. Check query location, tags, and log.
# Bronxdale: 3 healthcare POIs
# Brooklyn Heights: 32 healthcare POIs
# Brooklyn Navy Yard: 2 healthcare POIs
# Brownsville: 5 healthcare POIs
# Bushwick North: 15 healthcare POIs
# Bushwick South: 11 healthcare POIs
# Cambria Heights: 3 healthcare POIs
# Canarsie: 5 healthcare POIs
# Carroll Gardens: 15 healthcare POIs
# Central Harlem: 13 healthcare POIs
# Central Harlem North: 7 healthcare POIs
# Central Park failed: No matching features. Check query location, tags, and log.
# Charleston/Tottenville: 12 healthcare POIs
# Chinatown: 22 healthcare POIs
# City Island: 3 healthcare POIs
# Claremont/Bathgate: 4 healthcare POIs
# Clinton East: 13 healthcare POIs
# Clinton Hill: 24 healthcare POIs
# Clinton West: 5 healthcare POIs
# Co-Op City: 1 healthcare POIs
# Cobble Hill: 14 healthcare POIs
# College Point failed: No matching features. Check query location, tags, and log.
# Columbia Street: 1 healthcare POIs
# Coney Island: 14 healthcare POIs
# Corona: 11 healthcare POIs
# Corona failed: No matching features. Check query location, tags, and log.
# Country Club failed: No matching features. Check query location, tags, and log.
# Crotona Park failed: No matching features. Check query location, tags, and log.
# Crotona Park East: 3 healthcare POIs
# Crown Heights North: 24 healthcare POIs
# Crown Heights South: 7 healthcare POIs
# Cypress Hills: 1 healthcare POIs
# Douglaston: 3 healthcare POIs
# Downtown Brooklyn/MetroTech: 6 healthcare POIs
# DUMBO/Vinegar Hill: 2 healthcare POIs
# Dyker Heights: 5 healthcare POIs
# East Chelsea: 12 healthcare POIs
# East Concourse/Concourse Village: 3 healthcare POIs
# East Elmhurst failed: No matching features. Check query location, tags, and log.
# East Flatbush/Farragut: 3 healthcare POIs
# East Flatbush/Remsen Village: 2 healthcare POIs
# East Flushing: 3 healthcare POIs
# East Harlem North: 17 healthcare POIs
# East Harlem South: 26 healthcare POIs
# East New York: 3 healthcare POIs
# East New York/Pennsylvania Avenue: 1 healthcare POIs
# East Tremont: 4 healthcare POIs
# East Village: 19 healthcare POIs
# East Williamsburg: 12 healthcare POIs
# Eastchester: 1 healthcare POIs
# Elmhurst: 42 healthcare POIs
# Elmhurst/Maspeth: 9 healthcare POIs
# Eltingville/Annadale/Prince's Bay: 17 healthcare POIs
# Erasmus: 5 healthcare POIs
# Far Rockaway: 3 healthcare POIs
# Financial District North: 11 healthcare POIs
# Financial District South: 4 healthcare POIs
# Flatbush/Ditmas Park: 28 healthcare POIs
# Flatiron: 9 healthcare POIs
# Flatlands: 7 healthcare POIs
# Flushing: 30 healthcare POIs
# Flushing Meadows-Corona Park failed: No matching features. Check query location, tags, and log.
# Fordham South: 9 healthcare POIs
# Forest Hills: 109 healthcare POIs
# Forest Park/Highland Park failed: No matching features. Check query location, tags, and log.
# Fort Greene: 20 healthcare POIs
# Fresh Meadows: 8 healthcare POIs
# Freshkills Park: 1 healthcare POIs
# Garment District: 5 healthcare POIs
# Glen Oaks: 18 healthcare POIs
# Glendale: 6 healthcare POIs
# Governor's Island/Ellis Island/Liberty Island failed: No matching features. Check query location, tags, and log.
# Governor's Island/Ellis Island/Liberty Island failed: No matching features. Check query location, tags, and log.
# Governor's Island/Ellis Island/Liberty Island failed: No matching features. Check query location, tags, and log.
# Gowanus: 8 healthcare POIs
# Gramercy: 33 healthcare POIs
# Gravesend: 6 healthcare POIs
# Great Kills: 42 healthcare POIs
# Great Kills Park failed: No matching features. Check query location, tags, and log.
# Green-Wood Cemetery failed: No matching features. Check query location, tags, and log.
# Greenpoint: 25 healthcare POIs
# Greenwich Village North: 11 healthcare POIs
# Greenwich Village South: 3 healthcare POIs
# Grymes Hill/Clifton: 3 healthcare POIs
# Hamilton Heights: 4 healthcare POIs
# Hammels/Arverne: 4 healthcare POIs
# Heartland Village/Todt Hill: 12 healthcare POIs
# Highbridge failed: No matching features. Check query location, tags, and log.
# Highbridge Park failed: No matching features. Check query location, tags, and log.
# Hillcrest/Pomonok: 12 healthcare POIs
# Hollis: 8 healthcare POIs
# Homecrest: 25 healthcare POIs
# Howard Beach: 2 healthcare POIs
# Hudson Sq: 1 healthcare POIs
# Hunts Point: 3 healthcare POIs
# Inwood: 4 healthcare POIs
# Inwood Hill Park: 1 healthcare POIs
# Jackson Heights: 30 healthcare POIs
# Jamaica: 58 healthcare POIs
# Jamaica Estates: 36 healthcare POIs
# JFK Airport: 1 healthcare POIs
# Kensington: 29 healthcare POIs
# Kew Gardens: 24 healthcare POIs
# Kew Gardens Hills: 11 healthcare POIs
# Kingsbridge Heights: 3 healthcare POIs
# Kips Bay: 20 healthcare POIs
# LaGuardia Airport failed: No matching features. Check query location, tags, and log.
# Laurelton: 6 healthcare POIs
# Lenox Hill East: 19 healthcare POIs
# Lenox Hill West: 24 healthcare POIs
# Lincoln Square East: 7 healthcare POIs
# Lincoln Square West: 10 healthcare POIs
# Little Italy/NoLiTa: 20 healthcare POIs
# Long Island City/Hunters Point: 19 healthcare POIs
# Long Island City/Queens Plaza: 4 healthcare POIs
# Longwood: 1 healthcare POIs
# Lower East Side: 11 healthcare POIs
# Madison: 15 healthcare POIs
# Manhattan Beach: 3 healthcare POIs
# Manhattan Valley: 17 healthcare POIs
# Manhattanville: 3 healthcare POIs
# Marble Hill: 1 healthcare POIs
# Marine Park/Floyd Bennett Field failed: No matching features. Check query location, tags, and log.
# Marine Park/Mill Basin: 1 healthcare POIs
# Mariners Harbor: 4 healthcare POIs
# Maspeth: 25 healthcare POIs
# Meatpacking/West Village West failed: No matching features. Check query location, tags, and log.
# Melrose South: 6 healthcare POIs
# Middle Village: 18 healthcare POIs
# Midtown Center: 10 healthcare POIs
# Midtown East: 14 healthcare POIs
# Midtown North: 9 healthcare POIs
# Midtown South: 7 healthcare POIs
# Midwood: 13 healthcare POIs
# Morningside Heights: 11 healthcare POIs
# Morrisania/Melrose: 3 healthcare POIs
# Mott Haven/Port Morris: 3 healthcare POIs
# Mount Hope: 11 healthcare POIs
# Murray Hill: 42 healthcare POIs
# Murray Hill-Queens: 2 healthcare POIs
# New Dorp/Midland Beach: 24 healthcare POIs
# North Corona: 10 healthcare POIs
# Norwood: 10 healthcare POIs
# Oakland Gardens: 17 healthcare POIs
# Oakwood: 4 healthcare POIs
# Ocean Hill: 3 healthcare POIs
# Ocean Parkway South failed: No matching features. Check query location, tags, and log.
# Old Astoria: 12 healthcare POIs
# Ozone Park: 3 healthcare POIs
# Park Slope: 130 healthcare POIs
# Parkchester: 12 healthcare POIs
# Pelham Bay: 4 healthcare POIs
# Pelham Bay Park failed: No matching features. Check query location, tags, and log.
# Pelham Parkway: 9 healthcare POIs
# Penn Station/Madison Sq West: 5 healthcare POIs
# Port Richmond: 6 healthcare POIs
# Prospect-Lefferts Gardens: 25 healthcare POIs
# Prospect Heights: 22 healthcare POIs
# Prospect Park failed: No matching features. Check query location, tags, and log.
# Queens Village: 19 healthcare POIs
# Queensboro Hill: 3 healthcare POIs
# Queensbridge/Ravenswood: 1 healthcare POIs
# Randalls Island: 3 healthcare POIs
# Red Hook: 3 healthcare POIs
# Rego Park: 18 healthcare POIs
# Richmond Hill: 22 healthcare POIs
# Ridgewood: 28 healthcare POIs
# Rikers Island failed: No matching features. Check query location, tags, and log.
# Riverdale/North Riverdale/Fieldston: 1 healthcare POIs
# Rockaway Park: 4 healthcare POIs
# Roosevelt Island: 2 healthcare POIs
# Rosedale: 1 healthcare POIs
# Rossville/Woodrow: 1 healthcare POIs
# Saint Albans: 6 healthcare POIs
# Saint George/New Brighton: 9 healthcare POIs
# Saint Michaels Cemetery/Woodside failed: No matching features. Check query location, tags, and log.
# Schuylerville/Edgewater Park: 5 healthcare POIs
# Seaport: 4 healthcare POIs
# Sheepshead Bay: 16 healthcare POIs
# SoHo: 3 healthcare POIs
# Soundview/Bruckner: 5 healthcare POIs
# Soundview/Castle Hill: 4 healthcare POIs
# South Beach/Dongan Hills: 35 healthcare POIs
# South Jamaica: 3 healthcare POIs
# South Ozone Park: 18 healthcare POIs
# South Williamsburg: 4 healthcare POIs
# Springfield Gardens North: 1 healthcare POIs
# Springfield Gardens South failed: No matching features. Check query location, tags, and log.
# Spuyten Duyvil/Kingsbridge: 8 healthcare POIs
# Stapleton: 6 healthcare POIs
# Starrett City failed: No matching features. Check query location, tags, and log.
# Steinway: 25 healthcare POIs
# Stuy Town/Peter Cooper Village: 1 healthcare POIs
# Stuyvesant Heights: 7 healthcare POIs
# Sunnyside: 19 healthcare POIs
# Sunset Park East: 24 healthcare POIs
# Sunset Park West: 39 healthcare POIs
# Sutton Place/Turtle Bay North: 7 healthcare POIs
# Times Sq/Theatre District: 4 healthcare POIs
# TriBeCa/Civic Center: 33 healthcare POIs
# Two Bridges/Seward Park: 11 healthcare POIs
# UN/Turtle Bay South: 5 healthcare POIs
# Union Sq: 24 healthcare POIs
# University Heights/Morris Heights: 1 healthcare POIs
# Upper East Side North: 28 healthcare POIs
# Upper East Side South: 19 healthcare POIs
# Upper West Side North: 19 healthcare POIs
# Upper West Side South: 12 healthcare POIs
# Van Cortlandt Park failed: No matching features. Check query location, tags, and log.
# Van Cortlandt Village: 2 healthcare POIs
# Van Nest/Morris Park: 8 healthcare POIs
# Washington Heights North: 12 healthcare POIs
# Washington Heights South: 21 healthcare POIs
# West Brighton: 11 healthcare POIs
# West Chelsea/Hudson Yards: 2 healthcare POIs
# West Concourse: 3 healthcare POIs
# West Farms/Bronx River: 3 healthcare POIs
# West Village: 9 healthcare POIs
# Westchester Village/Unionport: 2 healthcare POIs
# Westerleigh: 19 healthcare POIs
# Whitestone: 2 healthcare POIs
# Willets Point failed: No matching features. Check query location, tags, and log.
# Williamsbridge/Olinville: 5 healthcare POIs
# Williamsburg (North Side): 13 healthcare POIs
# Williamsburg (South Side): 8 healthcare POIs
# Windsor Terrace: 11 healthcare POIs
# Woodhaven: 1 healthcare POIs
# Woodlawn/Wakefield: 5 healthcare POIs
# Woodside: 18 healthcare POIs
# World Trade Center: 4 healthcare POIs
# Yorkville East: 5 healthcare POIs
# Yorkville West: 13 healthcare POIs

# %%
# Recalculate area in square miles
zones_proj["area_m2"] = zones_proj.geometry.area
zones_proj["area_miles2"] = zones_proj["area_m2"] / 2.59e6  # m² to mi²

# Define POI datasets and density column names
poi_gdfs = {
    "nightlife": nightlife_gdf,
    "education": education_gdf,
    "healthcare": healthcare_gdf,
    "venues": venues_gdf,
    "tourism": tourism_gdf,
    "hotel": hotels_gdf,
    "transit": transit_gdf,
    "restaurants": restaurants_gdf
}

poi_density_features = {
    "nightlife": "nightlife_density_per_sq_mile",
    "education": "education_density_per_sq_mile",
    "healthcare": "healthcare_density_per_sq_mile",
    "venues": "venues_density_per_sq_mile",
    "tourism": "tourism_density_per_sq_mile",
    "hotel": "hotel_density_per_sq_mile",
    "transit": "transit_density_per_sq_mile",
    "restaurants": "restaurant_density_per_sq_mile"
}

# Initialize zones_stats with geometry and area
zones_stats = zones_proj[["zone", "LocationID", "geometry", "area_miles2"]].copy()

# Process each POI category
for category, gdf in poi_gdfs.items():
    print(f"Processing: {category}")
    
    # Spatial join POIs to zones
    joined = gpd.sjoin(gdf, zones_proj, how="inner", predicate="within")
    
    # Handle potential column mismatch (zone or zone_right)
    zone_col = "zone_right" if "zone_right" in joined.columns else "zone"
    
    # Count POIs per zone
    poi_counts = joined.groupby(zone_col).size().reset_index(name=f"{category}_count")
    poi_counts.rename(columns={zone_col: "zone"}, inplace=True)
    
    # Merge counts into zones_stats
    zones_stats = zones_stats.merge(poi_counts, on="zone", how="left")
    zones_stats[f"{category}_count"] = zones_stats[f"{category}_count"].fillna(0)
    
    # Compute density
    zones_stats[poi_density_features[category]] = zones_stats[f"{category}_count"] / zones_stats["area_miles2"]
# Out:
# Processing: nightlife
# Processing: education
# Processing: healthcare
# Processing: venues
# Processing: tourism
# Processing: hotel
# Processing: transit
# Processing: restaurants

# %%
zones_stats.drop(columns="geometry").to_csv("zone_stats_with_all_densities.csv", index=False)

# %%
print([col for col in zones_stats.columns if "density" in col.lower()])
# Out:
# ['nightlife_density_per_sq_mile', 'education_density_per_sq_mile', 'healthcare_density_per_sq_mile', 'venues_density_per_sq_mile', 'tourism_density_per_sq_mile', 'hotel_density_per_sq_mile', 'transit_density_per_sq_mile', 'restaurant_density_per_sq_mile']
